# %% [markdown]
# # Analysing the connection between a commit and the numbers of issues introduced by it and duplicated issues
# In the version 1 data, each issue is defined by the ID of the commit it got introduced in and (if solved) which commit fixed the issue. For version 2, an analysis key is given to each issue that links it to the commit over another table. It is to be investigated whether the two data versions both display a link to the introducing commit by investigating how the metrics of the analysis link to the issues. It is expected that there can be one or more issues for each analysis. <br>
# Another investigation is necessary to understand whether known code smells are repeatedly found and noted for each commit or whether already identified errors are listed again for each analysis or not. The expectation is that known issues aren't repeatedly listed if already identified.

# %%
import pandas as pd
import numpy as np
import os

# %%
# data import
current_dir = os.getcwd()

# construct path to the project data folder
data_dir = os.path.join(current_dir, '..', '..', 'Data','Sonar_Issues')

# load SonarQube measure data
df1 = pd.read_csv(os.path.join(data_dir, 'SONAR_ISSUES_v1.csv'))
df2 = pd.read_csv(os.path.join(data_dir, 'SONAR_ISSUES_v2.csv'))

data_dir2 = os.path.join(current_dir, '..', '..', 'Data','Sonar_Measures')
v1_metr = pd.read_csv(os.path.join(data_dir2, 'SONAR_MEASURES_V1.csv'), low_memory = False)
v2_metr = pd.read_csv(os.path.join(data_dir2, 'SONAR_MEASURES_V2.csv'), low_memory = False)

# %% [markdown]
# ## Connection between a commit and the numbers of issues
# To better understand the connection between a commit and the linked issues, a small project is chosen and the counts of issues per commit are counted in both dataset versions.

# %%
df1.groupby('projectID').count().sort_values(by = "creationDate")
# Out:
#                        creationDate  closeDate  creationCommitHash  \
# projectID
# commons-daemon                  393         91                 393
# commons-dbutils                 644        303                 644
# commons-exec                    762        448                 762
# commons-fileupload              769        482                 769
# commons-codec                  2041        903                2041
# commons-validator              2050       1165                2050
# commons-dbcp                   3696       2686                3696
# commons-vfs                    3719       2387                3719
# commons-ognl                   4945       3885                4945
# commons-digester               4947       4947                4947
# commons-jxpath                 4951       2632                4951
# zookeeper                      5023        629                5023
# commons-jelly                  5060       5060                5060
# commons-beanutils              5182       1892                5182
# commons-configuration          5612       3816                5612
# commons-io                     5849       3153                5849
# aurora                         7526       6422                7526
# commons-bcel                   8449       4125                8449
# mina-sshd                      9031       5755                9031
# httpcomponents-core            9531       5899                9531
# httpcomponents-client         10803       7345               10803
# commons-collections           11118       7632               11118
# felix                         11340       2464               11340
# santuario                     22398      17355               22398
# batik                         31691      17436               31691
# commons-jexl                  34994      33887               34994
# atlas                         35776      29136               35776
# commons-cli                   37408      36810               37408
# commons-net                   41340      38981               41340
# ambari                        41612      24957               41612
# cocoon                        58073      43262               58073
# beam                          85018      79151               85018
# accumulo                    1429757    1421955             1429757
#
#                        closeCommitHash     type    squid  component  severity  \
# projectID
# commons-daemon                      91      393      393        393       393
# commons-dbutils                    303      644      644        644       644
# commons-exec                       448      762      762        762       762
# commons-fileupload                 482      769      769        769       769
# commons-codec                      903     2041     2041       2041      2041
# commons-validator                 1165     2050     2050       2050      2050
# commons-dbcp                      2681     3696     3696       3696      3696
# commons-vfs                       2387     3719     3719       3719      3719
# commons-ognl                      3885     4945     4945       4945      4945
# commons-digester                  3756     4947     4947       4947      4947
# commons-jxpath                    2632     4951     4951       4951      4951
# zookeeper                          617     5023     5023       5023      5023
# commons-jelly                     2905     5060     5060       5060      5060
# commons-beanutils                 1888     5182     5182       5182      5182
# commons-configuration             3816     5612     5612       5612      5612
# commons-io                        3153     5849     5849       5849      5849
# aurora                            6422     7526     7526       7526      7526
# commons-bcel                      4125     8449     8449       8449      8449
# mina-sshd                         5755     9031     9031       9031      9031
# httpcomponents-core               5899     9531     9531       9531      9531
# httpcomponents-client             7337    10803    10803      10803     10803
# commons-collections               7632    11118    11118      11118     11118
# felix                             2464    11340    11340      11340     11340
# santuario                        17355    22398    22398      22398     22398
# batik                            17436    31691    31691      31691     31691
# commons-jexl                     33887    34994    34994      34994     34994
# atlas                            29136    35776    35776      35776     35776
# commons-cli                      36810    37408    37408      37408     37408
# commons-net                      38981    41340    41340      41340     41340
# ambari                           24957    41612    41612      41612     41612
# cocoon                           43262    58073    58073      58073     58073
# beam                             79151    85018    85018      85018     85018
# accumulo                       1421955  1429757  1429757    1429757   1429757
#
#                        project  startLine  endLine  resolution   status  \
# projectID
# commons-daemon             393        375      375          91      393
# commons-dbutils            644        570      570         303      644
# commons-exec               762        702      702         448      762
# commons-fileupload         769        695      695         482      769
# commons-codec             2041       1972     1972         903     2041
# commons-validator         2050       1897     1897        1165     2050
# commons-dbcp              3696       3567     3567        2686     3696
# commons-vfs               3719       3514     3514        2387     3719
# commons-ognl              4945       4746     4746        3885     4945
# commons-digester          4947       4529     4529        4947     4947
# commons-jxpath            4951       4876     4876        2632     4951
# zookeeper                 5023       4851     4851         629     5023
# commons-jelly             5060       4476     4476        5060     5060
# commons-beanutils         5182       5058     5058        1892     5182
# commons-configuration     5612       5153     5153        3816     5612
# commons-io                5849       5737     5737        3153     5849
# aurora                    7526       7401     7401        6422     7526
# commons-bcel              8449       7723     7723        4125     8449
# mina-sshd                 9031       8650     8650        5755     9031
# httpcomponents-core       9531       8664     8664        5899     9531
# httpcomponents-client    10803      10215    10215        7345    10803
# commons-collections      11118      10557    10557        7632    11118
# felix                    11340      10694    10694        2464    11340
# santuario                22398      20862    20862       17355    22398
# batik                    31691      30301    30301       17436    31691
# commons-jexl             34994      34774    34774       33887    34994
# atlas                    35776      34387    34387       29136    35776
# commons-cli              37408      33397    33397       36810    37408
# commons-net              41340      37854    37854       38981    41340
# ambari                   41612      40162    40162       24957    41612
# cocoon                   58073      53338    53338       43262    58073
# beam                     85018      82788    82788       79151    85018
# accumulo               1429757    1372931  1372931     1421955  1429757
#
#                        message   effort     debt   author
# projectID
# commons-daemon             393      393      393      393
# commons-dbutils            644      644      626      644
# commons-exec               762      762      738      758
# commons-fileupload         769      769      717      769
# commons-codec             2041     2041     1985     2041
# commons-validator         2050     2050     1979     2050
# commons-dbcp              3696     3696     3657     3695
# commons-vfs               3719     3719     3539     3719
# commons-ognl              4945     4945     4913     4945
# commons-digester          4947     4947     4922     4947
# commons-jxpath            4951     4951     4937     4946
# zookeeper                 5023     5023     4974     5023
# commons-jelly             5060     5060     5008     5030
# commons-beanutils         5182     5182     5118     5182
# commons-configuration     5612     5612     5521     5611
# commons-io                5849     5849     5782     5849
# aurora                    7526     7526     6493     7518
# commons-bcel              8449     8449     7988     8446
# mina-sshd                 9031     9031     8411     9031
# httpcomponents-core       9531     9531     9503     9531
# httpcomponents-client    10803    10803    10699    10800
# commons-collections      11118    11118    10906    11118
# felix                    11340    11340    10941    11252
# santuario                22398    22398    22074    22344
# batik                    31691    31691    31350    31646
# commons-jexl             34994    34994    34877    27038
# atlas                    35776    35776    34005    33131
# commons-cli              37408    37408    36362    32815
# commons-net              41340    41340    40879    35134
# ambari                   41612    41612    39460    41210
# cocoon                   58073    58073    55997    58052
# beam                     85018    85018    83149    84309
# accumulo               1429757  1429757  1419517  1064778

# %% [markdown]
# Based on the overview, commons-daemon is chosen as the project to investigate the connection between issues and metrics.

# %%
df1[df1["projectID"] == "commons-daemon"]
# Out:
#           projectID          creationDate             closeDate  \
# 0    commons-daemon  2003-09-04T23:28:19Z                   NaN
# 1    commons-daemon  2003-09-04T23:28:19Z  2010-03-15T08:09:26Z
# 2    commons-daemon  2003-09-04T23:28:19Z  2010-03-15T08:09:26Z
# 3    commons-daemon  2003-09-04T23:28:19Z  2010-03-15T08:09:26Z
# 4    commons-daemon  2003-09-04T23:28:19Z  2010-03-15T08:09:26Z
# ..              ...                   ...                   ...
# 388  commons-daemon  2011-06-02T16:29:44Z                   NaN
# 389  commons-daemon  2011-06-02T16:29:44Z                   NaN
# 390  commons-daemon  2011-06-02T16:29:44Z                   NaN
# 391  commons-daemon  2011-08-01T20:31:34Z                   NaN
# 392  commons-daemon  2011-08-01T20:31:34Z                   NaN
#
#                            creationCommitHash  \
# 0    d3416d3a25b16da3d18b3849522fa96183918e5b
# 1    d3416d3a25b16da3d18b3849522fa96183918e5b
# 2    d3416d3a25b16da3d18b3849522fa96183918e5b
# 3    d3416d3a25b16da3d18b3849522fa96183918e5b
# 4    d3416d3a25b16da3d18b3849522fa96183918e5b
# ..                                        ...
# 388  d352d2cc3a2da86da4573d200d471452a327b3bb
# 389  d352d2cc3a2da86da4573d200d471452a327b3bb
# 390  d352d2cc3a2da86da4573d200d471452a327b3bb
# 391  5a5aed907aae4ac8aa544a4ee010ccfd92747105
# 392  5a5aed907aae4ac8aa544a4ee010ccfd92747105
#
#                               closeCommitHash        type         squid  \
# 0                                         NaN  CODE_SMELL  squid:S00112
# 1    6cbc872eb202dfc27f2eb59b02d953c3deca32c8  CODE_SMELL  squid:S00122
# 2    6cbc872eb202dfc27f2eb59b02d953c3deca32c8  CODE_SMELL  squid:S00122
# 3    6cbc872eb202dfc27f2eb59b02d953c3deca32c8  CODE_SMELL  squid:S00122
# 4    6cbc872eb202dfc27f2eb59b02d953c3deca32c8  CODE_SMELL  squid:S00122
# ..                                        ...         ...           ...
# 388                                       NaN  CODE_SMELL    squid:S106
# 389                                       NaN  CODE_SMELL    squid:S106
# 390                                       NaN  CODE_SMELL    squid:S106
# 391                                       NaN  CODE_SMELL   squid:S1166
# 392                                       NaN  CODE_SMELL  squid:S00108
#
#                                              component  severity  \
# 0    org.apache:daemon:src/main/java/org/apache/com...     MAJOR
# 1    org.apache:deamon:src/java/org/apache/commons/...     MINOR
# 2    org.apache:deamon:src/java/org/apache/commons/...     MINOR
# 3    org.apache:deamon:src/java/org/apache/commons/...     MINOR
# 4    org.apache:deamon:src/java/org/apache/commons/...     MINOR
# ..                                                 ...       ...
# 388  org.apache:daemon:src/main/java/org/apache/com...     MAJOR
# 389  org.apache:daemon:src/test/java/org/apache/com...     MAJOR
# 390  org.apache:daemon:src/test/java/org/apache/com...     MAJOR
# 391  org.apache:daemon:src/main/java/org/apache/com...  CRITICAL
# 392  org.apache:daemon:src/main/java/org/apache/com...     MAJOR
#
#                project  startLine  endLine resolution  status  \
# 0    org.apache:daemon       71.0     71.0        NaN    OPEN
# 1    org.apache:daemon      265.0    265.0      FIXED  CLOSED
# 2    org.apache:daemon      259.0    259.0      FIXED  CLOSED
# 3    org.apache:daemon      261.0    261.0      FIXED  CLOSED
# 4    org.apache:daemon      278.0    278.0      FIXED  CLOSED
# ..                 ...        ...      ...        ...     ...
# 388  org.apache:daemon      110.0    110.0        NaN    OPEN
# 389  org.apache:daemon      162.0    162.0        NaN    OPEN
# 390  org.apache:daemon      164.0    164.0        NaN    OPEN
# 391  org.apache:daemon      104.0    104.0        NaN    OPEN
# 392  org.apache:daemon      104.0    104.0        NaN    OPEN
#
#                                                message  effort   debt  \
# 0    Define and throw a dedicated exception instead...      20  20min
# 1    At most one statement is allowed per line, but...       1   1min
# 2    At most one statement is allowed per line, but...       1   1min
# 3    At most one statement is allowed per line, but...       1   1min
# 4    At most one statement is allowed per line, but...       1   1min
# ..                                                 ...     ...    ...
# 388  Replace this use of System.out or System.err b...      10  10min
# 389  Replace this use of System.out or System.err b...      10  10min
# 390  Replace this use of System.out or System.err b...      10  10min
# 391              Either log or rethrow this exception.      10  10min
# 392          Either remove or fill this block of code.       5   5min
#
#                author
# 0    yoavs@apache.org
# 1    yoavs@apache.org
# 2    yoavs@apache.org
# 3    yoavs@apache.org
# 4    yoavs@apache.org
# ..                ...
# 388  mturk@apache.org
# 389  mturk@apache.org
# 390  mturk@apache.org
# 391  mturk@apache.org
# 392  mturk@apache.org
#
# [393 rows x 18 columns]

# %%
v1_metr[v1_metr["projectID"] == "commons-daemon"]
# Out:
#                                      commitHash       projectID  \
# 48573  49cbb142a2b5d7d89aab077dc63f7646828c9408  commons-daemon
# 48574  5e90dbea078fca205d913efc8e61ba278c5f39d8  commons-daemon
# 48575  6c0eafee28fc5c8ab69215df31dc4f07c5579a34  commons-daemon
# 48576  7b73ce30f32318b99056fee53397c08063d6f661  commons-daemon
# 48577  7c9d9cde24a00cde7e584136355ce5e048e11e5e  commons-daemon
# ...                                         ...             ...
# 49548  4962bb2786a7ef6ff9d1b4913b14c1a0c24b800f  commons-daemon
# 49549  75111d90afe15b1222449b401ca94dbe13d4e667  commons-daemon
# 49550  a3ff183a3d78f2264baebf716b46f01c71e0d6b8  commons-daemon
# 49551  e87cfbabd73f8c6a0895731799732294c26511bb  commons-daemon
# 49552  e395486132ba9033b679f703b6f9443ef28af239  commons-daemon
#
#              SQAnalysisDate  classes  files  functions  commentLines  \
# 48573  2003-09-04T23:28:20Z        0      0          0             0
# 48574  2003-09-04T23:42:57Z       15     11         87           274
# 48575  2003-09-05T08:50:36Z       15     11         87           274
# 48576  2003-09-12T09:05:57Z       15     11         87           274
# 48577  2003-09-12T09:08:51Z       15     11         87           274
# ...                     ...      ...    ...        ...           ...
# 49548  2017-12-08T20:55:20Z       24     39        169           993
# 49549  2018-01-07T20:41:45Z       24     39        169           993
# 49550  2018-04-08T17:04:51Z       24     39        169           993
# 49551  2018-04-08T17:15:45Z       24     39        169           993
# 49552  2018-05-15T18:22:50Z       24     39        169           993
#
#        commentLinesDensity  complexity  fileComplexity  ...  \
# 48573                  0.0           0             0.0  ...
# 48574                 23.0         153            13.9  ...
# 48575                 23.0         153            13.9  ...
# 48576                 23.0         153            13.9  ...
# 48577                 23.0         153            13.9  ...
# ...                    ...         ...             ...  ...
# 49548                 17.7         328            15.6  ...
# 49549                 17.7         328            15.6  ...
# 49550                 17.7         328            15.6  ...
# 49551                 17.7         328            15.6  ...
# 49552                 17.7         328            15.6  ...
#
#                                       qualityGateDetails  \
# 48573  {"level":"OK","conditions":[{"metric":"blocker...
# 48574  {"level":"ERROR","conditions":[{"metric":"bloc...
# 48575  {"level":"ERROR","conditions":[{"metric":"bloc...
# 48576  {"level":"ERROR","conditions":[{"metric":"bloc...
# 48577  {"level":"ERROR","conditions":[{"metric":"bloc...
# ...                                                  ...
# 49548  {"level":"ERROR","conditions":[{"metric":"bloc...
# 49549  {"level":"ERROR","conditions":[{"metric":"bloc...
# 49550  {"level":"ERROR","conditions":[{"metric":"bloc...
# 49551  {"level":"ERROR","conditions":[{"metric":"bloc...
# 49552  {"level":"ERROR","conditions":[{"metric":"bloc...
#
#                                          qualityProfiles newSqaleDebtRatio  \
# 48573                                                  0          0.000000
# 48574  [{"key":"java-sonar-way-04122","language":"jav...          0.000000
# 48575  [{"key":"java-sonar-way-04122","language":"jav...          0.000000
# 48576  [{"key":"java-sonar-way-04122","language":"jav...          0.000000
# 48577  [{"key":"java-sonar-way-04122","language":"jav...          0.000000
# ...                                                  ...               ...
# 49548  [{"key":"css-sonar-way-41536","language":"css"...          6.128205
# 49549  [{"key":"css-sonar-way-41536","language":"css"...          6.081425
# 49550  [{"key":"css-sonar-way-41536","language":"css"...          6.081425
# 49551  [{"key":"css-sonar-way-41536","language":"css"...          5.945274
# 49552  [{"key":"css-sonar-way-41536","language":"css"...          5.945274
#
#       vulnerabilities  reliabilityRemediationEffort  reliabilityRating  \
# 48573               0                             0                  1
# 48574               0                            85                  4
# 48575               0                            85                  4
# 48576               0                            85                  4
# 48577               0                            85                  4
# ...               ...                           ...                ...
# 49548               0                           125                  4
# 49549               0                           125                  4
# 49550               0                           125                  4
# 49551               0                           125                  4
# 49552               0                           125                  4
#
#        securityRemediationEffort  securityRating  wontFixIssues  \
# 48573                          0               1              0
# 48574                          0               1              0
# 48575                          0               1              0
# 48576                          0               1              0
# 48577                          0               1              0
# ...                          ...             ...            ...
# 49548                          0               1              0
# 49549                          0               1              0
# 49550                          0               1              0
# 49551                          0               1              0
# 49552                          0               1              0
#
#        packageDependencyCycles
# 48573                        0
# 48574                        0
# 48575                        0
# 48576                        0
# 48577                        0
# ...                        ...
# 49548                        0
# 49549                        0
# 49550                        0
# 49551                        0
# 49552                        0
#
# [980 rows x 61 columns]

# %%
df2[df2["PROJECT_ID"] == "org.apache:daemon"]
# Out:
#                PROJECT_ID CREATION_ANALYSIS_KEY             ISSUE_KEY  \
# 317524  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYIM2JIufLPH4zmf5
# 317525  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYIM2JIufLPH4zmf8
# 317526  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYIM2JIufLPH4zmf9
# 317527  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYIM2JIufLPH4zmf-
# 317528  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYINFJIufLPH4zmf_
# ...                   ...                   ...                   ...
# 318315  org.apache:daemon  AWMBlR-dB1UEtThguyc1  AWMBlSKQB1UEtThguydo
# 318316  org.apache:daemon  AWMBmmI_B1UEtThguyfc  AWMBmmYpB1UEtThguyfd
# 318317  org.apache:daemon  AWMBmmI_B1UEtThguyfc  AWMBmmYsB1UEtThguyfe
# 318318  org.apache:daemon  AWMBmmI_B1UEtThguyfc  AWMBmmYsB1UEtThguyff
# 318319  org.apache:daemon  AWMBmmI_B1UEtThguyfc  AWMBmmYtB1UEtThguyfg
#
#               TYPE                                   RULE SEVERITY  STATUS  \
# 317524  CODE_SMELL                           squid:S00112    MAJOR    OPEN
# 317525  CODE_SMELL  squid:RedundantThrowsDeclarationCheck    MINOR  CLOSED
# 317526  CODE_SMELL  squid:RedundantThrowsDeclarationCheck    MINOR  CLOSED
# 317527  CODE_SMELL  squid:RedundantThrowsDeclarationCheck    MINOR  CLOSED
# 317528  CODE_SMELL  squid:RedundantThrowsDeclarationCheck    MINOR  CLOSED
# ...            ...                                    ...      ...     ...
# 318315  CODE_SMELL                       xml:NewlineCheck    MINOR    OPEN
# 318316  CODE_SMELL                        xml:IndentCheck    MINOR    OPEN
# 318317  CODE_SMELL                        xml:IndentCheck    MINOR    OPEN
# 318318  CODE_SMELL                       xml:NewlineCheck    MINOR    OPEN
# 318319  CODE_SMELL                       xml:NewlineCheck    MINOR    OPEN
#
#        RESOLUTION  EFFORT  DEBT  ...  \
# 317524        NaN    20.0  20.0  ...
# 317525      FIXED     5.0   5.0  ...
# 317526      FIXED     5.0   5.0  ...
# 317527      FIXED     5.0   5.0  ...
# 317528      FIXED     5.0   5.0  ...
# ...           ...     ...   ...  ...
# 318315        NaN     2.0   2.0  ...
# 318316        NaN     1.0   1.0  ...
# 318317        NaN     1.0   1.0  ...
# 318318        NaN     2.0   2.0  ...
# 318319        NaN     2.0   2.0  ...
#
#                                                   MESSAGE  \
# 317524  Define and throw a dedicated exception instead...
# 317525  Remove the declaration of thrown exception 'ja...
# 317526  Remove the declaration of thrown exception 'ja...
# 317527  Remove the declaration of thrown exception 'ja...
# 317528  Remove the declaration of thrown exception 'ja...
# ...                                                   ...
# 318315                 Missing newline after last element
# 318316                  Make this line start at column 9.
# 318317                 Make this line start at column 11.
# 318318                 Missing newline after last element
# 318319            Start every element on a separate line.
#
#                                                 COMPONENT START_LINE END_LINE  \
# 317524  org.apache:daemon:src/main/java/org/apache/com...       71.0     71.0
# 317525  org.apache:deamon:src/java/org/apache/commons/...       32.0     32.0
# 317526  org.apache:deamon:src/java/org/apache/commons/...       38.0     38.0
# 317527  org.apache:deamon:src/java/org/apache/commons/...       44.0     44.0
# 317528  org.apache:deamon:src/java/org/apache/commons/...       50.0     50.0
# ...                                                   ...        ...      ...
# 318315        org.apache:daemon:src/site/xdoc/procrun.xml      315.0    315.0
# 318316   org.apache:daemon:src/native/unix/man/jsvc.1.xml       50.0     50.0
# 318317   org.apache:daemon:src/native/unix/man/jsvc.1.xml      151.0    151.0
# 318318   org.apache:daemon:src/native/unix/man/jsvc.1.xml       50.0     50.0
# 318319   org.apache:daemon:src/native/unix/man/jsvc.1.xml      151.0    151.0
#
#        START_OFFSET  END_OFFSET  HASH  FROM_HOTSPOT  NOT_FOUND  \
# 317524         36.0        45.0   NaN           NaN          0
# 317525         11.0        32.0   NaN           NaN          0
# 317526         11.0        32.0   NaN           NaN          0
# 317527         11.0        32.0   NaN           NaN          0
# 317528         11.0        32.0   NaN           NaN          0
# ...             ...         ...   ...           ...        ...
# 318315          0.0        76.0   NaN           NaN          0
# 318316          0.0        84.0   NaN           NaN          0
# 318317          0.0        65.0   NaN           NaN          0
# 318318          0.0        84.0   NaN           NaN          0
# 318319          0.0        65.0   NaN           NaN          0
#
#           CLOSE_ANALYSIS_KEY
# 317524                   NaN
# 317525  AV3d8DdiJIufLPH4znah
# 317526  AV3d8DdiJIufLPH4znah
# 317527  AV3d8DdiJIufLPH4znah
# 317528  AV3d8DdiJIufLPH4znah
# ...                      ...
# 318315                   NaN
# 318316                   NaN
# 318317                   NaN
# 318318                   NaN
# 318319                   NaN
#
# [796 rows x 23 columns]

# %%
v2_metr[v2_metr["PROJECT_ID"] == "org.apache:daemon"]
# Out:
#               PROJECT_ID          ANALYSIS_KEY  COMPLEXITY  FILE_COMPLEXITY  \
# 35963  org.apache:daemon  AWZ-LXaXaNRaZ0AgbEtg       328.0             15.6
# 35964  org.apache:daemon  AWZ-LCWiaNRaZ0AgbEs4       328.0             15.6
# 35965  org.apache:daemon  AWRHygpN5esBcMsFz0-R       328.0             15.6
# 35966  org.apache:daemon  AWMBs0KTB1UEtThguylM       328.0             15.6
# 35967  org.apache:daemon  AWMBszm1B1UEtThguylH       328.0             15.6
# ...                  ...                   ...         ...              ...
# 36939  org.apache:daemon  AV3dYalIJIufLPH4zmjc       153.0             13.9
# 36940  org.apache:daemon  AV3dYV7wJIufLPH4zmjR       153.0             13.9
# 36941  org.apache:daemon  AV3dYQ3SJIufLPH4zmjM       153.0             13.9
# 36942  org.apache:daemon  AV3dYMyEJIufLPH4zmjH       153.0             13.9
# 36943  org.apache:daemon  AV3dYIDUJIufLPH4zmfo       153.0             13.9
#
#        COMPLEXITY_IN_CLASSES  CLASS_COMPLEXITY  COMPLEXITY_IN_FUNCTIONS  \
# 35963                  299.0              12.5                    326.0
# 35964                    NaN              12.5                      NaN
# 35965                    NaN              12.5                      NaN
# 35966                    NaN              12.5                      NaN
# 35967                    NaN              12.5                      NaN
# ...                      ...               ...                      ...
# 36939                    NaN              10.2                      NaN
# 36940                    NaN              10.2                      NaN
# 36941                    NaN              10.2                      NaN
# 36942                    NaN              10.2                      NaN
# 36943                    NaN              10.2                      NaN
#
#        FUNCTION_COMPLEXITY  CLASS_COMPLEXITY_DISTRIBUTION  \
# 35963                  1.9                            NaN
# 35964                  1.9                            NaN
# 35965                  1.9                            NaN
# 35966                  1.9                            NaN
# 35967                  1.9                            NaN
# ...                    ...                            ...
# 36939                  1.8                            NaN
# 36940                  1.8                            NaN
# 36941                  1.8                            NaN
# 36942                  1.8                            NaN
# 36943                  1.8                            NaN
#
#        FUNCTION_COMPLEXITY_DISTRIBUTION  ...  \
# 35963  1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# 35964  1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# 35965  1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# 35966  1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# 35967  1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# ...                                 ...  ...
# 36939   1=50,2=13,4=6,6=0,8=3,10=2,12=0  ...
# 36940   1=50,2=13,4=6,6=0,8=3,10=2,12=0  ...
# 36941   1=50,2=13,4=6,6=0,8=3,10=2,12=0  ...
# 36942   1=50,2=13,4=6,6=0,8=3,10=2,12=0  ...
# 36943   1=50,2=13,4=6,6=0,8=3,10=2,12=0  ...
#
#       sg_i.JAVA_CYCLIC_PACKAGES_PERCENT  sg_i.MAX_MODULE_NCCD  \
# 35963                               NaN                   NaN
# 35964                               NaN                   NaN
# 35965                               NaN                   NaN
# 35966                               NaN                   NaN
# 35967                               NaN                   NaN
# ...                                 ...                   ...
# 36939                               NaN                   NaN
# 36940                               NaN                   NaN
# 36941                               NaN                   NaN
# 36942                               NaN                   NaN
# 36943                               NaN                   NaN
#
#        sg_i.ARCHITECTURE_FEATURE_AVAILABLE  sg_i.NUMBER_OF_ISSUES  \
# 35963                                  NaN                    NaN
# 35964                                  NaN                    NaN
# 35965                                  NaN                    NaN
# 35966                                  NaN                    NaN
# 35967                                  NaN                    NaN
# ...                                    ...                    ...
# 36939                                  NaN                    NaN
# 36940                                  NaN                    NaN
# 36941                                  NaN                    NaN
# 36942                                  NaN                    NaN
# 36943                                  NaN                    NaN
#
#        sg_i.NUMBER_OF_CRITICAL_ISSUES_WITHOUT_RESOLUTION  \
# 35963                                                NaN
# 35964                                                NaN
# 35965                                                NaN
# 35966                                                NaN
# 35967                                                NaN
# ...                                                  ...
# 36939                                                NaN
# 36940                                                NaN
# 36941                                                NaN
# 36942                                                NaN
# 36943                                                NaN
#
#        sg_i.VIOLATING_COMPONENTS_PERCENT  sg_i.UNASSIGNED_COMPONENTS_PERCENT  \
# 35963                                NaN                                 NaN
# 35964                                NaN                                 NaN
# 35965                                NaN                                 NaN
# 35966                                NaN                                 NaN
# 35967                                NaN                                 NaN
# ...                                  ...                                 ...
# 36939                                NaN                                 NaN
# 36940                                NaN                                 NaN
# 36941                                NaN                                 NaN
# 36942                                NaN                                 NaN
# 36943                                NaN                                 NaN
#
#        sg_i.NUMBER_OF_THRESHOLD_VIOLATIONS  sg_i.NUMBER_OF_WORKSPACE_WARNINGS  \
# 35963                                  NaN                                NaN
# 35964                                  NaN                                NaN
# 35965                                  NaN                                NaN
# 35966                                  NaN                                NaN
# 35967                                  NaN                                NaN
# ...                                    ...                                ...
# 36939                                  NaN                                NaN
# 36940                                  NaN                                NaN
# 36941                                  NaN                                NaN
# 36942                                  NaN                                NaN
# 36943                                  NaN                                NaN
#
#        sg_i.NUMBER_OF_IGNORED_CRITICAL_ISSUES
# 35963                                     NaN
# 35964                                     NaN
# 35965                                     NaN
# 35966                                     NaN
# 35967                                     NaN
# ...                                       ...
# 36939                                     NaN
# 36940                                     NaN
# 36941                                     NaN
# 36942                                     NaN
# 36943                                     NaN
#
# [981 rows x 240 columns]

# %%
merged_df = pd.merge(v2_metr[v2_metr["PROJECT_ID"] == "org.apache:daemon"], df2[df2["PROJECT_ID"] == "org.apache:daemon"], left_on='ANALYSIS_KEY', right_on='CREATION_ANALYSIS_KEY', how='inner')
merged_df
# Out:
#           PROJECT_ID_x          ANALYSIS_KEY  COMPLEXITY  FILE_COMPLEXITY  \
# 0    org.apache:daemon  AWMBmmI_B1UEtThguyfc       328.0             15.6
# 1    org.apache:daemon  AWMBmmI_B1UEtThguyfc       328.0             15.6
# 2    org.apache:daemon  AWMBmmI_B1UEtThguyfc       328.0             15.6
# 3    org.apache:daemon  AWMBmmI_B1UEtThguyfc       328.0             15.6
# 4    org.apache:daemon  AWMBlR-dB1UEtThguyc1       328.0             15.6
# ..                 ...                   ...         ...              ...
# 578  org.apache:daemon  AV3dZ4SdJIufLPH4zmlm       164.0             13.7
# 579  org.apache:daemon  AV3dZ4SdJIufLPH4zmlm       164.0             13.7
# 580  org.apache:daemon  AV3dZ4SdJIufLPH4zmlm       164.0             13.7
# 581  org.apache:daemon  AV3dZ4SdJIufLPH4zmlm       164.0             13.7
# 582  org.apache:daemon  AV3dZ4SdJIufLPH4zmlm       164.0             13.7
#
#      COMPLEXITY_IN_CLASSES  CLASS_COMPLEXITY  COMPLEXITY_IN_FUNCTIONS  \
# 0                      NaN              12.5                      NaN
# 1                      NaN              12.5                      NaN
# 2                      NaN              12.5                      NaN
# 3                      NaN              12.5                      NaN
# 4                      NaN              12.5                      NaN
# ..                     ...               ...                      ...
# 578                    NaN              10.3                      NaN
# 579                    NaN              10.3                      NaN
# 580                    NaN              10.3                      NaN
# 581                    NaN              10.3                      NaN
# 582                    NaN              10.3                      NaN
#
#      FUNCTION_COMPLEXITY  CLASS_COMPLEXITY_DISTRIBUTION  \
# 0                    1.9                            NaN
# 1                    1.9                            NaN
# 2                    1.9                            NaN
# 3                    1.9                            NaN
# 4                    1.9                            NaN
# ..                   ...                            ...
# 578                  1.8                            NaN
# 579                  1.8                            NaN
# 580                  1.8                            NaN
# 581                  1.8                            NaN
# 582                  1.8                            NaN
#
#      FUNCTION_COMPLEXITY_DISTRIBUTION  ...  \
# 0    1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# 1    1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# 2    1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# 3    1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# 4    1=80,2=35,4=10,6=1,8=4,10=0,12=4  ...
# ..                                ...  ...
# 578   1=52,2=16,4=6,6=0,8=2,10=3,12=0  ...
# 579   1=52,2=16,4=6,6=0,8=2,10=3,12=0  ...
# 580   1=52,2=16,4=6,6=0,8=2,10=3,12=0  ...
# 581   1=52,2=16,4=6,6=0,8=2,10=3,12=0  ...
# 582   1=52,2=16,4=6,6=0,8=2,10=3,12=0  ...
#
#                                                MESSAGE  \
# 0                    Make this line start at column 9.
# 1                   Make this line start at column 11.
# 2                   Missing newline after last element
# 3              Start every element on a separate line.
# 4                    Make this line start at column 3.
# ..                                                 ...
# 578        Remove this unused import 'java.util.Date'.
# 579  Remove this unused import 'java.text.SimpleDat...
# 580      Do not override the Object.finalize() method.
# 581  Refactor this method to throw at most one chec...
# 582       2 duplicated blocks of code must be removed.
#
#                                             COMPONENT  START_LINE  END_LINE  \
# 0    org.apache:daemon:src/native/unix/man/jsvc.1.xml        50.0      50.0
# 1    org.apache:daemon:src/native/unix/man/jsvc.1.xml       151.0     151.0
# 2    org.apache:daemon:src/native/unix/man/jsvc.1.xml        50.0      50.0
# 3    org.apache:daemon:src/native/unix/man/jsvc.1.xml       151.0     151.0
# 4         org.apache:daemon:src/site/xdoc/procrun.xml        20.0      20.0
# ..                                                ...         ...       ...
# 578   org.apache:daemon:src/samples/AloneService.java        23.0      23.0
# 579   org.apache:daemon:src/samples/AloneService.java        22.0      22.0
# 580   org.apache:daemon:src/samples/AloneService.java        35.0      35.0
# 581   org.apache:daemon:src/samples/AloneService.java       101.0     101.0
# 582   org.apache:daemon:src/samples/AloneService.java         NaN       NaN
#
#      START_OFFSET  END_OFFSET  HASH  FROM_HOTSPOT  NOT_FOUND  \
# 0             0.0        84.0   NaN           NaN          0
# 1             0.0        65.0   NaN           NaN          0
# 2             0.0        84.0   NaN           NaN          0
# 3             0.0        65.0   NaN           NaN          0
# 4             0.0        13.0   NaN           NaN          0
# ..            ...         ...   ...           ...        ...
# 578           0.0        22.0   NaN           NaN          0
# 579           0.0        34.0   NaN           NaN          0
# 580          19.0        27.0   NaN           NaN          0
# 581          16.0        20.0   NaN           NaN          0
# 582           NaN         NaN   NaN           NaN          0
#
#        CLOSE_ANALYSIS_KEY
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 578  AV3eA5a4JIufLPH4znj7
# 579  AV3eA5a4JIufLPH4znj7
# 580                   NaN
# 581  AV3eBGaLJIufLPH4znkP
# 582                   NaN
#
# [583 rows x 263 columns]

# %%
merged_df['ANALYSIS_KEY'].value_counts().sort_values(ascending=False)
# Out:
# ANALYSIS_KEY
# AWMBlOSiB1UEtThguyWS    348
# AWMBlR-dB1UEtThguyc1     51
# AV3eHnTFJIufLPH4zn2k     45
# AV3dZ4SdJIufLPH4zmlm     26
# AV3eGQfIJIufLPH4znz7     24
# AV3eMJC9JIufLPH4zn-N      9
# AV3eGKwbJIufLPH4znzn      9
# AV3eILrPJIufLPH4zn4R      8
# AV3d--o5JIufLPH4znga      6
# AV3eIIBWJIufLPH4zn4F      6
# AV3eGZ6pJIufLPH4zn0l      6
# AV3djCRBJIufLPH4zm2y      4
# AV3eIcCHJIufLPH4zn43      4
# AWMBmmI_B1UEtThguyfc      4
# AV3dewd6JIufLPH4zmxs      4
# AV3daDS3JIufLPH4zmmW      4
# AV3eHzPAJIufLPH4zn3i      3
# AV3eECXGJIufLPH4znpU      3
# AV3eGSqxJIufLPH4zn0Y      3
# AV3eIP0XJIufLPH4zn4e      2
# AV3d_r6IJIufLPH4znhz      2
# AV3d8DdiJIufLPH4znah      2
# AV3dh0QDJIufLPH4zm1W      2
# AV3eJNT9JIufLPH4zn6B      2
# AV3eNoGQJIufLPH4zoAZ      2
# AV3eA5a4JIufLPH4znj7      1
# AV3d_O_xJIufLPH4znhA      1
# AV3eIYYeJIufLPH4zn4w      1
# AV3dmwTSJIufLPH4zm7B      1
# Name: count, dtype: int64

# %%
merged_df2 = pd.merge(v1_metr[v1_metr["projectID"] == "commons-daemon"], df1[df1["projectID"] == "commons-daemon"], left_on='commitHash', right_on='creationCommitHash', how='inner')
merged_df2
# Out:
#                                    commitHash     projectID_x  \
# 0    139615aebe97ec81dc22fca5cd2bdd46a1b8cc95  commons-daemon
# 1    139615aebe97ec81dc22fca5cd2bdd46a1b8cc95  commons-daemon
# 2    139615aebe97ec81dc22fca5cd2bdd46a1b8cc95  commons-daemon
# 3    139615aebe97ec81dc22fca5cd2bdd46a1b8cc95  commons-daemon
# 4    139615aebe97ec81dc22fca5cd2bdd46a1b8cc95  commons-daemon
# ..                                        ...             ...
# 175  d352d2cc3a2da86da4573d200d471452a327b3bb  commons-daemon
# 176  d352d2cc3a2da86da4573d200d471452a327b3bb  commons-daemon
# 177  d352d2cc3a2da86da4573d200d471452a327b3bb  commons-daemon
# 178  5a5aed907aae4ac8aa544a4ee010ccfd92747105  commons-daemon
# 179  5a5aed907aae4ac8aa544a4ee010ccfd92747105  commons-daemon
#
#            SQAnalysisDate  classes  files  functions  commentLines  \
# 0    2003-09-27T15:45:02Z       16     12         92           320
# 1    2003-09-27T15:45:02Z       16     12         92           320
# 2    2003-09-27T15:45:02Z       16     12         92           320
# 3    2003-09-27T15:45:02Z       16     12         92           320
# 4    2003-09-27T15:45:02Z       16     12         92           320
# ..                    ...      ...    ...        ...           ...
# 175  2011-06-02T16:29:44Z       24     17        151           591
# 176  2011-06-02T16:29:44Z       24     17        151           591
# 177  2011-06-02T16:29:44Z       24     17        151           591
# 178  2011-08-01T20:31:34Z       24     17        151           591
# 179  2011-08-01T20:31:34Z       24     17        151           591
#
#      commentLinesDensity  complexity  fileComplexity  ...  severity  \
# 0                   24.2         164            13.7  ...     MINOR
# 1                   24.2         164            13.7  ...     MAJOR
# 2                   24.2         164            13.7  ...     MAJOR
# 3                   24.2         164            13.7  ...     MINOR
# 4                   24.2         164            13.7  ...     MINOR
# ..                   ...         ...             ...  ...       ...
# 175                 24.3         297            17.5  ...     MAJOR
# 176                 24.3         297            17.5  ...     MAJOR
# 177                 24.3         297            17.5  ...     MAJOR
# 178                 24.2         298            17.5  ...  CRITICAL
# 179                 24.2         298            17.5  ...     MAJOR
#
#                project startLine endLine  resolution  status  \
# 0    org.apache:daemon       NaN     NaN       FIXED  CLOSED
# 1    org.apache:daemon      44.0    44.0         NaN    OPEN
# 2    org.apache:daemon      43.0    43.0         NaN    OPEN
# 3    org.apache:daemon      24.0    24.0       FIXED  CLOSED
# 4    org.apache:daemon      23.0    23.0       FIXED  CLOSED
# ..                 ...       ...     ...         ...     ...
# 175  org.apache:daemon     110.0   110.0         NaN    OPEN
# 176  org.apache:daemon     162.0   162.0         NaN    OPEN
# 177  org.apache:daemon     164.0   164.0         NaN    OPEN
# 178  org.apache:daemon     104.0   104.0         NaN    OPEN
# 179  org.apache:daemon     104.0   104.0         NaN    OPEN
#
#                                                message  effort   debt  \
# 0    Replace all tab characters in this file by seq...       2   2min
# 1    Define and throw a dedicated exception instead...      20  20min
# 2     Remove this unused method parameter "arguments".       5   5min
# 3    Remove this unused import 'java.util.Enumerati...       2   2min
# 4          Remove this unused import 'java.util.Date'.       2   2min
# ..                                                 ...     ...    ...
# 175  Replace this use of System.out or System.err b...      10  10min
# 176  Replace this use of System.out or System.err b...      10  10min
# 177  Replace this use of System.out or System.err b...      10  10min
# 178              Either log or rethrow this exception.      10  10min
# 179          Either remove or fill this block of code.       5   5min
#
#                  author
# 0    jfclere@apache.org
# 1    jfclere@apache.org
# 2    jfclere@apache.org
# 3    jfclere@apache.org
# 4    jfclere@apache.org
# ..                  ...
# 175    mturk@apache.org
# 176    mturk@apache.org
# 177    mturk@apache.org
# 178    mturk@apache.org
# 179    mturk@apache.org
#
# [180 rows x 79 columns]

# %%
merged_df2['commitHash'].value_counts().sort_values(ascending=False)
# Out:
# commitHash
# 394454a2e3e6acae0d24c8005af06372d5ffc37d    45
# 139615aebe97ec81dc22fca5cd2bdd46a1b8cc95    26
# 84cf9c0e47fc56ae243f9948ea98297907c13375    24
# d352d2cc3a2da86da4573d200d471452a327b3bb     9
# 787182423164028573b9b6c3579e7e79e984856e     9
# 5b0057535a564980c436c2345ad8939afaec1d99     8
# d0abf31b5dee5c8cb7f90fecdad57650bf1e373e     6
# 9e8cf8ed0dce1015f00393df82e5da5bc6a73859     6
# 5e8f67f1e44da42fcf8962375ab423030c2376f4     6
# 6d915afa8cd6eadae812e6cc89d3a422326a8fff     4
# 874c8f99a6e8002d6d780fa5214836ccc0cb9ce5     4
# d030f54c7257fb2d28fbbf0a60ce4d1426e04384     4
# 3f107c5fdc37610508e1218070101f405df02016     4
# 553415310feb587986ee05420b093856ea6c9572     3
# 1e09c60df58ce1c45c273deb35979ced7710cdad     3
# fe18fada3ad485c41a0e3dcaa01bc12a67a6d7ec     3
# 78f04f71d81372356ea39c701007109a779d0c1d     2
# dafda28bb17a44faaa235cf2eb7a8af323aec9ac     2
# ba9e8bef1f2f0c5166c0927836e40e62a0f9f38e     2
# 7bdbb56aca295e03797ca969c304d1d1602ca5e4     2
# 6cbc872eb202dfc27f2eb59b02d953c3deca32c8     2
# 5a5aed907aae4ac8aa544a4ee010ccfd92747105     2
# 662715efcce0284918cd7e9967e45f8c8b86dc02     1
# bc5d824aeea2bdc2f0299926d380bdecfe766c69     1
# 82689b83e1b0f6e7d61db9081ae544f6ddf4a56f     1
# 342338d960091e4cd701bbdddc7954505682a264     1
# Name: count, dtype: int64

# %% [markdown]
# Both data versions follow the same logic, an introduced code smell can be linked to the commit that introduced it. <br>
# How ever, some commits seem to introduce way more errors than others. It could be interferring with successfully modelling the issue tags and needs to be acknowledged when choosing a modelling approach.

# %% [markdown]
# ## Investigating the repetition of issues over different analysis
# To better understand how known issues are handled for each new commit and analysis, it is investigated whether there are duplicated issues over different commits for each dataset version.

# %% [markdown]
# #### Version 1

# %%
check = df1[df1["projectID"] == "commons-daemon"]
check
# Out:
#           projectID          creationDate             closeDate  \
# 0    commons-daemon  2003-09-04T23:28:19Z                   NaN
# 1    commons-daemon  2003-09-04T23:28:19Z  2010-03-15T08:09:26Z
# 2    commons-daemon  2003-09-04T23:28:19Z  2010-03-15T08:09:26Z
# 3    commons-daemon  2003-09-04T23:28:19Z  2010-03-15T08:09:26Z
# 4    commons-daemon  2003-09-04T23:28:19Z  2010-03-15T08:09:26Z
# ..              ...                   ...                   ...
# 388  commons-daemon  2011-06-02T16:29:44Z                   NaN
# 389  commons-daemon  2011-06-02T16:29:44Z                   NaN
# 390  commons-daemon  2011-06-02T16:29:44Z                   NaN
# 391  commons-daemon  2011-08-01T20:31:34Z                   NaN
# 392  commons-daemon  2011-08-01T20:31:34Z                   NaN
#
#                            creationCommitHash  \
# 0    d3416d3a25b16da3d18b3849522fa96183918e5b
# 1    d3416d3a25b16da3d18b3849522fa96183918e5b
# 2    d3416d3a25b16da3d18b3849522fa96183918e5b
# 3    d3416d3a25b16da3d18b3849522fa96183918e5b
# 4    d3416d3a25b16da3d18b3849522fa96183918e5b
# ..                                        ...
# 388  d352d2cc3a2da86da4573d200d471452a327b3bb
# 389  d352d2cc3a2da86da4573d200d471452a327b3bb
# 390  d352d2cc3a2da86da4573d200d471452a327b3bb
# 391  5a5aed907aae4ac8aa544a4ee010ccfd92747105
# 392  5a5aed907aae4ac8aa544a4ee010ccfd92747105
#
#                               closeCommitHash        type         squid  \
# 0                                         NaN  CODE_SMELL  squid:S00112
# 1    6cbc872eb202dfc27f2eb59b02d953c3deca32c8  CODE_SMELL  squid:S00122
# 2    6cbc872eb202dfc27f2eb59b02d953c3deca32c8  CODE_SMELL  squid:S00122
# 3    6cbc872eb202dfc27f2eb59b02d953c3deca32c8  CODE_SMELL  squid:S00122
# 4    6cbc872eb202dfc27f2eb59b02d953c3deca32c8  CODE_SMELL  squid:S00122
# ..                                        ...         ...           ...
# 388                                       NaN  CODE_SMELL    squid:S106
# 389                                       NaN  CODE_SMELL    squid:S106
# 390                                       NaN  CODE_SMELL    squid:S106
# 391                                       NaN  CODE_SMELL   squid:S1166
# 392                                       NaN  CODE_SMELL  squid:S00108
#
#                                              component  severity  \
# 0    org.apache:daemon:src/main/java/org/apache/com...     MAJOR
# 1    org.apache:deamon:src/java/org/apache/commons/...     MINOR
# 2    org.apache:deamon:src/java/org/apache/commons/...     MINOR
# 3    org.apache:deamon:src/java/org/apache/commons/...     MINOR
# 4    org.apache:deamon:src/java/org/apache/commons/...     MINOR
# ..                                                 ...       ...
# 388  org.apache:daemon:src/main/java/org/apache/com...     MAJOR
# 389  org.apache:daemon:src/test/java/org/apache/com...     MAJOR
# 390  org.apache:daemon:src/test/java/org/apache/com...     MAJOR
# 391  org.apache:daemon:src/main/java/org/apache/com...  CRITICAL
# 392  org.apache:daemon:src/main/java/org/apache/com...     MAJOR
#
#                project  startLine  endLine resolution  status  \
# 0    org.apache:daemon       71.0     71.0        NaN    OPEN
# 1    org.apache:daemon      265.0    265.0      FIXED  CLOSED
# 2    org.apache:daemon      259.0    259.0      FIXED  CLOSED
# 3    org.apache:daemon      261.0    261.0      FIXED  CLOSED
# 4    org.apache:daemon      278.0    278.0      FIXED  CLOSED
# ..                 ...        ...      ...        ...     ...
# 388  org.apache:daemon      110.0    110.0        NaN    OPEN
# 389  org.apache:daemon      162.0    162.0        NaN    OPEN
# 390  org.apache:daemon      164.0    164.0        NaN    OPEN
# 391  org.apache:daemon      104.0    104.0        NaN    OPEN
# 392  org.apache:daemon      104.0    104.0        NaN    OPEN
#
#                                                message  effort   debt  \
# 0    Define and throw a dedicated exception instead...      20  20min
# 1    At most one statement is allowed per line, but...       1   1min
# 2    At most one statement is allowed per line, but...       1   1min
# 3    At most one statement is allowed per line, but...       1   1min
# 4    At most one statement is allowed per line, but...       1   1min
# ..                                                 ...     ...    ...
# 388  Replace this use of System.out or System.err b...      10  10min
# 389  Replace this use of System.out or System.err b...      10  10min
# 390  Replace this use of System.out or System.err b...      10  10min
# 391              Either log or rethrow this exception.      10  10min
# 392          Either remove or fill this block of code.       5   5min
#
#                author
# 0    yoavs@apache.org
# 1    yoavs@apache.org
# 2    yoavs@apache.org
# 3    yoavs@apache.org
# 4    yoavs@apache.org
# ..                ...
# 388  mturk@apache.org
# 389  mturk@apache.org
# 390  mturk@apache.org
# 391  mturk@apache.org
# 392  mturk@apache.org
#
# [393 rows x 18 columns]

# %%
check.drop(columns = ["creationDate", "closeDate", "creationCommitHash", "closeCommitHash", "author"])[check.drop(columns = ["creationDate", "closeDate", "creationCommitHash", "closeCommitHash", "author"]).duplicated()]
# Out:
#           projectID        type                    squid  \
# 243  commons-daemon  CODE_SMELL  code_smells:long_method
# 244  commons-daemon  CODE_SMELL  code_smells:long_method
# 245  commons-daemon  CODE_SMELL  code_smells:long_method
# 246  commons-daemon  CODE_SMELL   code_smells:lazy_class
# 264  commons-daemon  CODE_SMELL  code_smells:long_method
#
#                                              component severity  \
# 243  org.apache:deamon:src/java/org/apache/commons/...    MAJOR
# 244  org.apache:deamon:src/java/org/apache/commons/...    MAJOR
# 245  org.apache:deamon:src/java/org/apache/commons/...    MAJOR
# 246  org.apache:daemon:src/samples/ServiceDaemonRea...    MAJOR
# 264  org.apache:daemon:src/samples/ProcrunService.java    MAJOR
#
#                project  startLine  endLine resolution  status      message  \
# 243  org.apache:daemon        1.0      1.0      FIXED  CLOSED  Long method
# 244  org.apache:daemon        1.0      1.0      FIXED  CLOSED  Long method
# 245  org.apache:daemon        1.0      1.0      FIXED  CLOSED  Long method
# 246  org.apache:daemon        1.0      1.0      FIXED  CLOSED   Lazy class
# 264  org.apache:daemon        1.0      1.0      FIXED  CLOSED  Long method
#
#      effort     debt
# 243      90  1h30min
# 244      90  1h30min
# 245      90  1h30min
# 246      90  1h30min
# 264      90  1h30min

# %% [markdown]
# There are only 5 duplicates for version 1, all showing fixed issues. Therefore there aren't any open issues duplicated for version 1.

# %% [markdown]
# #### Version 2

# %%
check = df2[df2["PROJECT_ID"] == "org.apache:daemon"]
check
# Out:
#                PROJECT_ID CREATION_ANALYSIS_KEY             ISSUE_KEY  \
# 317524  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYIM2JIufLPH4zmf5
# 317525  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYIM2JIufLPH4zmf8
# 317526  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYIM2JIufLPH4zmf9
# 317527  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYIM2JIufLPH4zmf-
# 317528  org.apache:daemon  AV3dX_FWJIufLPH4zmfP  AV3dYINFJIufLPH4zmf_
# ...                   ...                   ...                   ...
# 318315  org.apache:daemon  AWMBlR-dB1UEtThguyc1  AWMBlSKQB1UEtThguydo
# 318316  org.apache:daemon  AWMBmmI_B1UEtThguyfc  AWMBmmYpB1UEtThguyfd
# 318317  org.apache:daemon  AWMBmmI_B1UEtThguyfc  AWMBmmYsB1UEtThguyfe
# 318318  org.apache:daemon  AWMBmmI_B1UEtThguyfc  AWMBmmYsB1UEtThguyff
# 318319  org.apache:daemon  AWMBmmI_B1UEtThguyfc  AWMBmmYtB1UEtThguyfg
#
#               TYPE                                   RULE SEVERITY  STATUS  \
# 317524  CODE_SMELL                           squid:S00112    MAJOR    OPEN
# 317525  CODE_SMELL  squid:RedundantThrowsDeclarationCheck    MINOR  CLOSED
# 317526  CODE_SMELL  squid:RedundantThrowsDeclarationCheck    MINOR  CLOSED
# 317527  CODE_SMELL  squid:RedundantThrowsDeclarationCheck    MINOR  CLOSED
# 317528  CODE_SMELL  squid:RedundantThrowsDeclarationCheck    MINOR  CLOSED
# ...            ...                                    ...      ...     ...
# 318315  CODE_SMELL                       xml:NewlineCheck    MINOR    OPEN
# 318316  CODE_SMELL                        xml:IndentCheck    MINOR    OPEN
# 318317  CODE_SMELL                        xml:IndentCheck    MINOR    OPEN
# 318318  CODE_SMELL                       xml:NewlineCheck    MINOR    OPEN
# 318319  CODE_SMELL                       xml:NewlineCheck    MINOR    OPEN
#
#        RESOLUTION  EFFORT  DEBT  ...  \
# 317524        NaN    20.0  20.0  ...
# 317525      FIXED     5.0   5.0  ...
# 317526      FIXED     5.0   5.0  ...
# 317527      FIXED     5.0   5.0  ...
# 317528      FIXED     5.0   5.0  ...
# ...           ...     ...   ...  ...
# 318315        NaN     2.0   2.0  ...
# 318316        NaN     1.0   1.0  ...
# 318317        NaN     1.0   1.0  ...
# 318318        NaN     2.0   2.0  ...
# 318319        NaN     2.0   2.0  ...
#
#                                                   MESSAGE  \
# 317524  Define and throw a dedicated exception instead...
# 317525  Remove the declaration of thrown exception 'ja...
# 317526  Remove the declaration of thrown exception 'ja...
# 317527  Remove the declaration of thrown exception 'ja...
# 317528  Remove the declaration of thrown exception 'ja...
# ...                                                   ...
# 318315                 Missing newline after last element
# 318316                  Make this line start at column 9.
# 318317                 Make this line start at column 11.
# 318318                 Missing newline after last element
# 318319            Start every element on a separate line.
#
#                                                 COMPONENT START_LINE END_LINE  \
# 317524  org.apache:daemon:src/main/java/org/apache/com...       71.0     71.0
# 317525  org.apache:deamon:src/java/org/apache/commons/...       32.0     32.0
# 317526  org.apache:deamon:src/java/org/apache/commons/...       38.0     38.0
# 317527  org.apache:deamon:src/java/org/apache/commons/...       44.0     44.0
# 317528  org.apache:deamon:src/java/org/apache/commons/...       50.0     50.0
# ...                                                   ...        ...      ...
# 318315        org.apache:daemon:src/site/xdoc/procrun.xml      315.0    315.0
# 318316   org.apache:daemon:src/native/unix/man/jsvc.1.xml       50.0     50.0
# 318317   org.apache:daemon:src/native/unix/man/jsvc.1.xml      151.0    151.0
# 318318   org.apache:daemon:src/native/unix/man/jsvc.1.xml       50.0     50.0
# 318319   org.apache:daemon:src/native/unix/man/jsvc.1.xml      151.0    151.0
#
#        START_OFFSET  END_OFFSET  HASH  FROM_HOTSPOT  NOT_FOUND  \
# 317524         36.0        45.0   NaN           NaN          0
# 317525         11.0        32.0   NaN           NaN          0
# 317526         11.0        32.0   NaN           NaN          0
# 317527         11.0        32.0   NaN           NaN          0
# 317528         11.0        32.0   NaN           NaN          0
# ...             ...         ...   ...           ...        ...
# 318315          0.0        76.0   NaN           NaN          0
# 318316          0.0        84.0   NaN           NaN          0
# 318317          0.0        65.0   NaN           NaN          0
# 318318          0.0        84.0   NaN           NaN          0
# 318319          0.0        65.0   NaN           NaN          0
#
#           CLOSE_ANALYSIS_KEY
# 317524                   NaN
# 317525  AV3d8DdiJIufLPH4znah
# 317526  AV3d8DdiJIufLPH4znah
# 317527  AV3d8DdiJIufLPH4znah
# 317528  AV3d8DdiJIufLPH4znah
# ...                      ...
# 318315                   NaN
# 318316                   NaN
# 318317                   NaN
# 318318                   NaN
# 318319                   NaN
#
# [796 rows x 23 columns]

# %%
check.drop(columns = ["CREATION_ANALYSIS_KEY", "ISSUE_KEY"])[check.drop(columns = ["CREATION_ANALYSIS_KEY", "ISSUE_KEY"]).duplicated()]
# Out:
#                PROJECT_ID        TYPE              RULE SEVERITY STATUS  \
# 318086  org.apache:daemon  CODE_SMELL  xml:NewlineCheck    MINOR   OPEN
# 318099  org.apache:daemon  CODE_SMELL  xml:NewlineCheck    MINOR   OPEN
# 318112  org.apache:daemon  CODE_SMELL  xml:NewlineCheck    MINOR   OPEN
# 318124  org.apache:daemon  CODE_SMELL  xml:NewlineCheck    MINOR   OPEN
# 318136  org.apache:daemon  CODE_SMELL  xml:NewlineCheck    MINOR   OPEN
# 318307  org.apache:daemon  CODE_SMELL  xml:NewlineCheck    MINOR   OPEN
# 318308  org.apache:daemon  CODE_SMELL  xml:NewlineCheck    MINOR   OPEN
#
#        RESOLUTION  EFFORT  DEBT TAGS        CREATION_DATE  ...  \
# 318086        NaN     2.0   2.0  NaN  2017-10-20 07:48:15  ...
# 318099        NaN     2.0   2.0  NaN  2017-10-20 07:48:15  ...
# 318112        NaN     2.0   2.0  NaN  2017-10-20 07:48:15  ...
# 318124        NaN     2.0   2.0  NaN  2017-10-20 07:48:15  ...
# 318136        NaN     2.0   2.0  NaN  2017-10-20 07:48:15  ...
# 318307        NaN     2.0   2.0  NaN  2017-10-20 18:52:50  ...
# 318308        NaN     2.0   2.0  NaN  2017-10-20 18:52:50  ...
#
#                                         MESSAGE  \
# 318086  Start every element on a separate line.
# 318099  Start every element on a separate line.
# 318112  Start every element on a separate line.
# 318124  Start every element on a separate line.
# 318136  Start every element on a separate line.
# 318307  Start every element on a separate line.
# 318308       Missing newline after last element
#
#                                              COMPONENT START_LINE  END_LINE  \
# 318086  org.apache:daemon:src/site/xdoc/mail-lists.xml      106.0     106.0
# 318099  org.apache:daemon:src/site/xdoc/mail-lists.xml      124.0     124.0
# 318112  org.apache:daemon:src/site/xdoc/mail-lists.xml      142.0     142.0
# 318124  org.apache:daemon:src/site/xdoc/mail-lists.xml      159.0     159.0
# 318136  org.apache:daemon:src/site/xdoc/mail-lists.xml      192.0     192.0
# 318307     org.apache:daemon:src/site/xdoc/procrun.xml      268.0     268.0
# 318308     org.apache:daemon:src/site/xdoc/procrun.xml      268.0     268.0
#
#         START_OFFSET  END_OFFSET  HASH  FROM_HOTSPOT  NOT_FOUND  \
# 318086           0.0        97.0   NaN           NaN          0
# 318099           0.0        95.0   NaN           NaN          0
# 318112           0.0        98.0   NaN           NaN          0
# 318124           0.0        99.0   NaN           NaN          0
# 318136           0.0       113.0   NaN           NaN          0
# 318307           0.0        87.0   NaN           NaN          0
# 318308           0.0        87.0   NaN           NaN          0
#
#         CLOSE_ANALYSIS_KEY
# 318086                 NaN
# 318099                 NaN
# 318112                 NaN
# 318124                 NaN
# 318136                 NaN
# 318307                 NaN
# 318308                 NaN
#
# [7 rows x 21 columns]

# %% [markdown]
# For version 2, there are duplicated issues, that do however have their own CREATION_ANALYSIS_KEY and ISSUE_KEY. <br>
# At the same time, there are only 7 duplicated issues out of 796, showing that this is not commonly done for all issues but instead could be reintroduced errors by developers. In comparison to version 1, the duplicated issues are marked as open.
