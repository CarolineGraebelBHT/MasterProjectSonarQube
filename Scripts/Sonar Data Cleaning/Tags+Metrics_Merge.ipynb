# %% [markdown]
# # Preparing data for NN
# The software metrics need to be connected to the issue tags per commit via identificators.

# %%
import pandas as pd
import numpy as np
import os
import ast
from collections import Counter

# %%
# data import
current_dir = os.getcwd()

# construct path to the project data folder
data_dir = os.path.join(current_dir, '..', '..', 'Data','Sonar_Measures')

# load SonarQube measure data
dfm = pd.read_csv(os.path.join(data_dir, 'sonar_measures_v1_v2_no_statics.csv'), low_memory=False)

data_dir = os.path.join(current_dir, '..', '..', 'Data','Sonar_Issues')
dfi1 = pd.read_csv(os.path.join(data_dir, 'tags_commithash_v1.csv'))
dfi2 = pd.read_csv(os.path.join(data_dir, 'tags_analysiskey_v2.csv'))

# %%
dfm
# Out:
#                                      COMMIT_HASH PROJECT_ID  \
# 0       e0880e263e4bf8662ba3848405200473a25dfc9f   accumulo
# 1       e8774c5ec3a35e042f320540b5f7e66ebd2d9e87   accumulo
# 2       2032ebbd0ed90734da39ca238bbd10dee24d0030   accumulo
# 3       de297d4932e08625a5df146f0802041bb5aeb892   accumulo
# 4       34efaae87639a83b60fdb7274de4b45051025a3a   accumulo
# ...                                          ...        ...
# 140743                                       NaN        vfs
# 140744                                       NaN        vfs
# 140745                                       NaN        vfs
# 140746                                       NaN        vfs
# 140747                                       NaN        vfs
#
#            SQ_ANALYSIS_DATE  CLASSES   FILES  FUNCTIONS  COMMENT_LINES  \
# 0       2008-07-07 14:52:05   2108.0  1103.0    17295.0        13509.0
# 1       2008-07-07 12:31:47   2108.0  1103.0    17295.0        13507.0
# 2       2008-07-05 18:54:27   2108.0  1103.0    17295.0        13507.0
# 3       2008-07-03 20:21:40   2108.0  1103.0    17295.0        13507.0
# 4       2008-07-02 00:12:36   2108.0  1103.0    17295.0        13507.0
# ...                     ...      ...     ...        ...            ...
# 140743  2002-08-20 06:10:50     69.0    65.0      425.0         1536.0
# 140744  2002-08-20 02:57:02     69.0    65.0      422.0         1533.0
# 140745  2002-07-19 11:54:15     69.0    65.0      421.0         1513.0
# 140746  2002-07-18 16:47:24     69.0    65.0      421.0         1513.0
# 140747  2002-07-17 10:23:44     69.0    65.0      421.0         1513.0
#
#         COMMENT_LINES_DENSITY  COMPLEXITY  FILE_COMPLEXITY  ...  \
# 0                         6.2     43137.0             40.6  ...
# 1                         6.2     43137.0             40.6  ...
# 2                         6.2     43137.0             40.6  ...
# 3                         6.2     43137.0             40.6  ...
# 4                         6.2     43137.0             40.6  ...
# ...                       ...         ...              ...  ...
# 140743                   24.2       690.0             10.6  ...
# 140744                   24.1       693.0             10.7  ...
# 140745                   24.1       687.0             10.6  ...
# 140746                   24.1       687.0             10.6  ...
# 140747                   24.1       687.0             10.6  ...
#
#                                          QUALITY_PROFILES  \
# 0       [{"key":"css-sonar-way-41536","language":"css"...
# 1       [{"key":"css-sonar-way-41536","language":"css"...
# 2       [{"key":"css-sonar-way-41536","language":"css"...
# 3       [{"key":"css-sonar-way-41536","language":"css"...
# 4       [{"key":"css-sonar-way-41536","language":"css"...
# ...                                                   ...
# 140743  [{"key":"java-sonar-way-04122";"language":"jav...
# 140744  [{"key":"java-sonar-way-04122";"language":"jav...
# 140745  [{"key":"java-sonar-way-04122";"language":"jav...
# 140746  [{"key":"java-sonar-way-04122";"language":"jav...
# 140747  [{"key":"java-sonar-way-04122";"language":"jav...
#
#         NEW_SQALE_DEBT_RATIO VULNERABILITIES RELIABILITY_REMEDIATION_EFFORT  \
# 0                   0.000000             838                           7322
# 1                   0.222222             838                           7081
# 2                   0.222222             838                           7081
# 3                   0.674560             838                           7322
# 4                   0.671668             838                           7322
# ...                      ...             ...                            ...
# 140743              2.025316               1                              0
# 140744              2.184236               1                              0
# 140745              2.613333               1                              0
# 140746              2.613333               1                              0
# 140747              2.613333               1                              0
#
#         RELIABILITY_RATING  SECURITY_REMEDIATION_EFFORT  SECURITY_RATING  \
# 0                        5                         9505                4
# 1                        5                         9505                4
# 2                        5                         9505                4
# 3                        5                         9505                4
# 4                        5                         9505                4
# ...                    ...                          ...              ...
# 140743                   1                           30                4
# 140744                   1                           30                4
# 140745                   1                           30                4
# 140746                   1                           30                4
# 140747                   1                           30                4
#
#         database          ANALYSIS_KEY  DIRECTORIES
# 0       Version1                   NaN          NaN
# 1       Version1                   NaN          NaN
# 2       Version1                   NaN          NaN
# 3       Version1                   NaN          NaN
# 4       Version1                   NaN          NaN
# ...          ...                   ...          ...
# 140743  Version2  AV4Z-nYtG0XxMwG_Vh5b         14.0
# 140744  Version2  AV4Z-jElG0XxMwG_Vh5F         14.0
# 140745  Version2  AV4Z-fA0G0XxMwG_Vh47         14.0
# 140746  Version2  AV4Z-bDZG0XxMwG_Vh4x         14.0
# 140747  Version2  AV4Z-W8cG0XxMwG_VhzH         14.0
#
# [140748 rows x 55 columns]

# %% [markdown]
# ## Fixing project names
# Currently, apache commons names have a different naming scheme over the two database versions. They need to be fixed by deleting 'commons-' in the project IDs.

# %%
dfm['PROJECT_ID'].unique()
# Out:
# array(['accumulo', 'ambari', 'atlas', 'aurora', 'batik', 'beam', 'cocoon',
#        'commons-bcel', 'commons-beanutils', 'commons-cli',
#        'commons-codec', 'commons-collections', 'commons-configuration',
#        'commons-daemon', 'commons-dbcp', 'commons-dbutils',
#        'commons-digester', 'commons-exec', 'commons-fileupload',
#        'commons-io', 'commons-jelly', 'commons-jexl', 'commons-jxpath',
#        'commons-net', 'commons-ognl', 'commons-validator', 'commons-vfs',
#        'felix', 'httpcomponents-client', 'httpcomponents-core',
#        'mina-sshd', 'santuario', 'zookeeper', 'cayenne', 'archiva',
#        'bcel', 'beanutils', 'codec', 'collections', 'configuration',
#        'daemon', 'dbcp', 'dbutils', 'digester', 'hive', 'httpclient',
#        'httpcore', 'jxpath', 'net', 'ognl', 'thrift', 'validator', 'vfs'],
#       dtype=object)

# %%
# How many unique projects are in the data? - 39.
dfm['PROJECT_ID'] = dfm['PROJECT_ID'].str.replace('commons-', '')
len(dfm['PROJECT_ID'].unique())
# Out:
# 39

# %%
dfm['database'].unique()
# Out:
# array(['Version1', 'Version2'], dtype=object)

# %%
# How many unique projects are there for database version 1? - 33.
len(dfm[dfm['database'] == 'Version1']['PROJECT_ID'].unique())
# Out:
# 33

# %%
# How many unique projects are there for database version 2? - 39.
len(dfm[dfm['database'] == 'Version2']['PROJECT_ID'].unique())
# Out:
# 30

# %%
dfi1 = dfi1[['creationCommitHash', 'uniqueTags']]
dfi1.columns =  ['creationCommitHash', 'TAGS']
dfi1
# Out:
#                             creationCommitHash  \
# 0     0001f90914b418859eb9fa86903e89a793e48e9b
# 1     0010fcad01ce4ac5051a61bec349bd6ac397c994
# 2     001e87db6432867d72f59553359d0e4cee5cd31d
# 3     002e4de0d68ffab9af339283f02659472a1febe7
# 4     002f40f9d3ec65891b5faf086df404dd3c450600
# ...                                        ...
# 9437  ffb2c376f08ea23854f4fad4933005b34827d5a7
# 9438  ffcdbb17689ed325715a43dc407ca20348277a5a
# 9439  ffd4863413cdb91db6f21744ada1d0b4a1559626
# 9440  ffd8e16a8a418dce679e07a973d6ff9bb5b304aa
# 9441  ffe13cfcca913a3eff9cec27f0a3ad2b6dcedcc8
#
#                                                    TAGS
# 0     ['error-handling', 'cwe', 'design', 'cert', 'c...
# 1                                    ['brain-overload']
# 2                                        ['convention']
# 3           ['error-handling', 'cwe', 'cert', 'design']
# 4     ['error-handling', 'brain-overload', 'cwe', 'd...
# ...                                                 ...
# 9437  ['brain-overload', 'misra', 'bad-practice', 'u...
# 9438                                         ['clumsy']
# 9439  ['error-handling', 'cwe', 'convention', 'cert'...
# 9440  ['error-handling', 'brain-overload', 'clumsy',...
# 9441  ['clumsy', 'code-smell', 'suspicious', 'conven...
#
# [9442 rows x 2 columns]

# %%
# transform tags to strings
dfi1['TAGS'] = dfi1['TAGS'].apply(ast.literal_eval)
dfi1['TAGS'] = dfi1['TAGS'].apply(lambda x: ', '.join(x))
dfi1
# Out:
#                             creationCommitHash  \
# 0     0001f90914b418859eb9fa86903e89a793e48e9b
# 1     0010fcad01ce4ac5051a61bec349bd6ac397c994
# 2     001e87db6432867d72f59553359d0e4cee5cd31d
# 3     002e4de0d68ffab9af339283f02659472a1febe7
# 4     002f40f9d3ec65891b5faf086df404dd3c450600
# ...                                        ...
# 9437  ffb2c376f08ea23854f4fad4933005b34827d5a7
# 9438  ffcdbb17689ed325715a43dc407ca20348277a5a
# 9439  ffd4863413cdb91db6f21744ada1d0b4a1559626
# 9440  ffd8e16a8a418dce679e07a973d6ff9bb5b304aa
# 9441  ffe13cfcca913a3eff9cec27f0a3ad2b6dcedcc8
#
#                                                    TAGS
# 0         error-handling, cwe, design, cert, convention
# 1                                        brain-overload
# 2                                            convention
# 3                     error-handling, cwe, cert, design
# 4     error-handling, brain-overload, cwe, design, c...
# ...                                                 ...
# 9437  brain-overload, misra, bad-practice, unused, cert
# 9438                                             clumsy
# 9439  error-handling, cwe, convention, cert, suspicious
# 9440  error-handling, brain-overload, clumsy, cwe, d...
# 9441  clumsy, code-smell, suspicious, convention, an...
#
# [9442 rows x 2 columns]

# %%
dfi2['UNIQUE_TAGS'].iloc[0]
# Out:
# "['suspicious', 'error-handling', 'cert', 'bad-practice']"

# %%
dfi2 = dfi2[['CREATION_ANALYSIS_KEY', 'UNIQUE_TAGS']]
dfi2
# Out:
#      CREATION_ANALYSIS_KEY                                        UNIQUE_TAGS
# 0     AV0-6-3jt6tne_r58pUF  ['suspicious', 'error-handling', 'cert', 'bad-...
# 1     AV0-8Tovt6tne_r58pUY                                         ['clumsy']
# 2     AV0-9p72t6tne_r58pUo                                   ['bad-practice']
# 3     AV0-BQ2Et6tne_r58pCR                                         ['design']
# 4     AV0-LoN2t6tne_r58pFZ                                ['pitfall', 'cert']
# ...                    ...                                                ...
# 9688  AWentw92Z1vVHhGU4u0K  ['error-handling', 'confusing', 'bad-practice'...
# 9689  AWenw12KZ1vVHhGU4vEw                          ['convention', 'pitfall']
# 9690  AWenwUBsZ1vVHhGU4vAM  ['convention', 'brain-overload', 'cert', 'bad-...
# 9691  AWenyFZ8Z1vVHhGU4vLr  ['error-handling', 'cwe', 'cert', 'bad-practice']
# 9692  AWenyYdHZ1vVHhGU4vNW  ['psr2', 'brain-overload', 'clumsy', 'design',...
#
# [9693 rows x 2 columns]

# %%
dfi2['TAGS'] = dfi2['UNIQUE_TAGS'].apply(ast.literal_eval)
dfi2 = dfi2.drop(columns = 'UNIQUE_TAGS')
dfi2['TAGS'] = dfi2['TAGS'].apply(lambda x: ', '.join(x))
dfi2
# Out:
#      CREATION_ANALYSIS_KEY                                               TAGS
# 0     AV0-6-3jt6tne_r58pUF     suspicious, error-handling, cert, bad-practice
# 1     AV0-8Tovt6tne_r58pUY                                             clumsy
# 2     AV0-9p72t6tne_r58pUo                                       bad-practice
# 3     AV0-BQ2Et6tne_r58pCR                                             design
# 4     AV0-LoN2t6tne_r58pFZ                                      pitfall, cert
# ...                    ...                                                ...
# 9688  AWentw92Z1vVHhGU4u0K  error-handling, confusing, bad-practice, cert,...
# 9689  AWenw12KZ1vVHhGU4vEw                                convention, pitfall
# 9690  AWenwUBsZ1vVHhGU4vAM     convention, brain-overload, cert, bad-practice
# 9691  AWenyFZ8Z1vVHhGU4vLr            error-handling, cwe, cert, bad-practice
# 9692  AWenyYdHZ1vVHhGU4vNW  psr2, brain-overload, clumsy, design, cwe, mis...
#
# [9693 rows x 2 columns]

# %%
dfm_i = dfm.merge(dfi1, how = 'left', left_on = 'COMMIT_HASH', right_on = 'creationCommitHash')
dfm_i
# Out:
#                                      COMMIT_HASH PROJECT_ID  \
# 0       e0880e263e4bf8662ba3848405200473a25dfc9f   accumulo
# 1       e8774c5ec3a35e042f320540b5f7e66ebd2d9e87   accumulo
# 2       2032ebbd0ed90734da39ca238bbd10dee24d0030   accumulo
# 3       de297d4932e08625a5df146f0802041bb5aeb892   accumulo
# 4       34efaae87639a83b60fdb7274de4b45051025a3a   accumulo
# ...                                          ...        ...
# 140743                                       NaN        vfs
# 140744                                       NaN        vfs
# 140745                                       NaN        vfs
# 140746                                       NaN        vfs
# 140747                                       NaN        vfs
#
#            SQ_ANALYSIS_DATE  CLASSES   FILES  FUNCTIONS  COMMENT_LINES  \
# 0       2008-07-07 14:52:05   2108.0  1103.0    17295.0        13509.0
# 1       2008-07-07 12:31:47   2108.0  1103.0    17295.0        13507.0
# 2       2008-07-05 18:54:27   2108.0  1103.0    17295.0        13507.0
# 3       2008-07-03 20:21:40   2108.0  1103.0    17295.0        13507.0
# 4       2008-07-02 00:12:36   2108.0  1103.0    17295.0        13507.0
# ...                     ...      ...     ...        ...            ...
# 140743  2002-08-20 06:10:50     69.0    65.0      425.0         1536.0
# 140744  2002-08-20 02:57:02     69.0    65.0      422.0         1533.0
# 140745  2002-07-19 11:54:15     69.0    65.0      421.0         1513.0
# 140746  2002-07-18 16:47:24     69.0    65.0      421.0         1513.0
# 140747  2002-07-17 10:23:44     69.0    65.0      421.0         1513.0
#
#         COMMENT_LINES_DENSITY  COMPLEXITY  FILE_COMPLEXITY  ...  \
# 0                         6.2     43137.0             40.6  ...
# 1                         6.2     43137.0             40.6  ...
# 2                         6.2     43137.0             40.6  ...
# 3                         6.2     43137.0             40.6  ...
# 4                         6.2     43137.0             40.6  ...
# ...                       ...         ...              ...  ...
# 140743                   24.2       690.0             10.6  ...
# 140744                   24.1       693.0             10.7  ...
# 140745                   24.1       687.0             10.6  ...
# 140746                   24.1       687.0             10.6  ...
# 140747                   24.1       687.0             10.6  ...
#
#         VULNERABILITIES  RELIABILITY_REMEDIATION_EFFORT RELIABILITY_RATING  \
# 0                   838                            7322                  5
# 1                   838                            7081                  5
# 2                   838                            7081                  5
# 3                   838                            7322                  5
# 4                   838                            7322                  5
# ...                 ...                             ...                ...
# 140743                1                               0                  1
# 140744                1                               0                  1
# 140745                1                               0                  1
# 140746                1                               0                  1
# 140747                1                               0                  1
#
#        SECURITY_REMEDIATION_EFFORT  SECURITY_RATING  database  \
# 0                             9505                4  Version1
# 1                             9505                4  Version1
# 2                             9505                4  Version1
# 3                             9505                4  Version1
# 4                             9505                4  Version1
# ...                            ...              ...       ...
# 140743                          30                4  Version2
# 140744                          30                4  Version2
# 140745                          30                4  Version2
# 140746                          30                4  Version2
# 140747                          30                4  Version2
#
#                 ANALYSIS_KEY  DIRECTORIES  \
# 0                        NaN          NaN
# 1                        NaN          NaN
# 2                        NaN          NaN
# 3                        NaN          NaN
# 4                        NaN          NaN
# ...                      ...          ...
# 140743  AV4Z-nYtG0XxMwG_Vh5b         14.0
# 140744  AV4Z-jElG0XxMwG_Vh5F         14.0
# 140745  AV4Z-fA0G0XxMwG_Vh47         14.0
# 140746  AV4Z-bDZG0XxMwG_Vh4x         14.0
# 140747  AV4Z-W8cG0XxMwG_VhzH         14.0
#
#                               creationCommitHash  \
# 0       e0880e263e4bf8662ba3848405200473a25dfc9f
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 140743                                       NaN
# 140744                                       NaN
# 140745                                       NaN
# 140746                                       NaN
# 140747                                       NaN
#
#                                                      TAGS
# 0       cwe, bad-practice, unused, cert, suspicious, j...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 140743                                                NaN
# 140744                                                NaN
# 140745                                                NaN
# 140746                                                NaN
# 140747                                                NaN
#
# [140748 rows x 57 columns]

# %%
dfm_i = dfm_i.merge(dfi2, how = 'left', left_on = 'ANALYSIS_KEY', right_on = 'CREATION_ANALYSIS_KEY')
dfm_i
# Out:
#                                      COMMIT_HASH PROJECT_ID  \
# 0       e0880e263e4bf8662ba3848405200473a25dfc9f   accumulo
# 1       e8774c5ec3a35e042f320540b5f7e66ebd2d9e87   accumulo
# 2       2032ebbd0ed90734da39ca238bbd10dee24d0030   accumulo
# 3       de297d4932e08625a5df146f0802041bb5aeb892   accumulo
# 4       34efaae87639a83b60fdb7274de4b45051025a3a   accumulo
# ...                                          ...        ...
# 140743                                       NaN        vfs
# 140744                                       NaN        vfs
# 140745                                       NaN        vfs
# 140746                                       NaN        vfs
# 140747                                       NaN        vfs
#
#            SQ_ANALYSIS_DATE  CLASSES   FILES  FUNCTIONS  COMMENT_LINES  \
# 0       2008-07-07 14:52:05   2108.0  1103.0    17295.0        13509.0
# 1       2008-07-07 12:31:47   2108.0  1103.0    17295.0        13507.0
# 2       2008-07-05 18:54:27   2108.0  1103.0    17295.0        13507.0
# 3       2008-07-03 20:21:40   2108.0  1103.0    17295.0        13507.0
# 4       2008-07-02 00:12:36   2108.0  1103.0    17295.0        13507.0
# ...                     ...      ...     ...        ...            ...
# 140743  2002-08-20 06:10:50     69.0    65.0      425.0         1536.0
# 140744  2002-08-20 02:57:02     69.0    65.0      422.0         1533.0
# 140745  2002-07-19 11:54:15     69.0    65.0      421.0         1513.0
# 140746  2002-07-18 16:47:24     69.0    65.0      421.0         1513.0
# 140747  2002-07-17 10:23:44     69.0    65.0      421.0         1513.0
#
#         COMMENT_LINES_DENSITY  COMPLEXITY  FILE_COMPLEXITY  ...  \
# 0                         6.2     43137.0             40.6  ...
# 1                         6.2     43137.0             40.6  ...
# 2                         6.2     43137.0             40.6  ...
# 3                         6.2     43137.0             40.6  ...
# 4                         6.2     43137.0             40.6  ...
# ...                       ...         ...              ...  ...
# 140743                   24.2       690.0             10.6  ...
# 140744                   24.1       693.0             10.7  ...
# 140745                   24.1       687.0             10.6  ...
# 140746                   24.1       687.0             10.6  ...
# 140747                   24.1       687.0             10.6  ...
#
#         RELIABILITY_RATING  SECURITY_REMEDIATION_EFFORT SECURITY_RATING  \
# 0                        5                         9505               4
# 1                        5                         9505               4
# 2                        5                         9505               4
# 3                        5                         9505               4
# 4                        5                         9505               4
# ...                    ...                          ...             ...
# 140743                   1                           30               4
# 140744                   1                           30               4
# 140745                   1                           30               4
# 140746                   1                           30               4
# 140747                   1                           30               4
#
#         database          ANALYSIS_KEY  DIRECTORIES  \
# 0       Version1                   NaN          NaN
# 1       Version1                   NaN          NaN
# 2       Version1                   NaN          NaN
# 3       Version1                   NaN          NaN
# 4       Version1                   NaN          NaN
# ...          ...                   ...          ...
# 140743  Version2  AV4Z-nYtG0XxMwG_Vh5b         14.0
# 140744  Version2  AV4Z-jElG0XxMwG_Vh5F         14.0
# 140745  Version2  AV4Z-fA0G0XxMwG_Vh47         14.0
# 140746  Version2  AV4Z-bDZG0XxMwG_Vh4x         14.0
# 140747  Version2  AV4Z-W8cG0XxMwG_VhzH         14.0
#
#                               creationCommitHash  \
# 0       e0880e263e4bf8662ba3848405200473a25dfc9f
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 140743                                       NaN
# 140744                                       NaN
# 140745                                       NaN
# 140746                                       NaN
# 140747                                       NaN
#
#                                                    TAGS_x  \
# 0       cwe, bad-practice, unused, cert, suspicious, j...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 140743                                                NaN
# 140744                                                NaN
# 140745                                                NaN
# 140746                                                NaN
# 140747                                                NaN
#
#         CREATION_ANALYSIS_KEY                                         TAGS_y
# 0                         NaN                                            NaN
# 1                         NaN                                            NaN
# 2                         NaN                                            NaN
# 3                         NaN                                            NaN
# 4                         NaN                                            NaN
# ...                       ...                                            ...
# 140743   AV4Z-nYtG0XxMwG_Vh5b               suspicious, error-handling, cert
# 140744   AV4Z-jElG0XxMwG_Vh5F               suspicious, error-handling, cert
# 140745                    NaN                                            NaN
# 140746                    NaN                                            NaN
# 140747   AV4Z-W8cG0XxMwG_VhzH  antipattern, clumsy, code-smell, bad-practice
#
# [140748 rows x 59 columns]

# %%
pd.set_option('display.max_rows', None)
missing_values = dfm_i.isnull().sum()
print("Missing Values per Column:")
print(missing_values)
pd.reset_option('display.max_rows')
# Out:
# Missing Values per Column:
# COMMIT_HASH                                  63079
# PROJECT_ID                                       0
# SQ_ANALYSIS_DATE                                 0
# CLASSES                                         20
# FILES                                           18
# FUNCTIONS                                       20
# COMMENT_LINES                                   18
# COMMENT_LINES_DENSITY                           18
# COMPLEXITY                                      20
# FILE_COMPLEXITY                                 20
# CLASS_COMPLEXITY                                20
# FUNCTION_COMPLEXITY                             20
# FUNCTION_COMPLEXITY_DISTRIBUTION              9875
# FILE_COMPLEXITY_DISTRIBUTION                    20
# DUPLICATED_LINES                                 0
# DUPLICATED_BLOCKS                                0
# DUPLICATED_FILES                                 0
# DUPLICATED_LINES_DENSITY                        18
# VIOLATIONS                                       0
# BLOCKER_VIOLATIONS                               0
# CRITICAL_VIOLATIONS                              0
# INFO_VIOLATIONS                                  0
# CONFIRMED_ISSUES                                 0
# LAST_COMMIT_DATE                                53
# CODE_SMELLS                                      0
# BUGS                                             0
# EFFORT_TO_REACH_MAINTAINABILITY_RATING_A         0
# COGNITIVE_COMPLEXITY                            20
# LINES                                           18
# NCLOC                                           18
# NCLOC_LANGUAGE_DISTRIBUTION                     18
# LINES_TO_COVER                                  26
# MAJOR_VIOLATIONS                                 0
# MINOR_VIOLATIONS                                 0
# OPEN_ISSUES                                      0
# SQALE_RATING                                     0
# MISSING_PACKAGE_INFO                             0
# PACKAGE                                          0
# STATEMENTS                                      20
# UNCOVERED_LINES                                 26
# SQALE_INDEX                                      0
# DEVELOPMENT_COST                                 0
# SQALE_DEBT_RATIO                                 0
# ALERT_STATUS                                     0
# QUALITY_GATE_DETAILS                             0
# QUALITY_PROFILES                                18
# NEW_SQALE_DEBT_RATIO                            10
# VULNERABILITIES                                  0
# RELIABILITY_REMEDIATION_EFFORT                   0
# RELIABILITY_RATING                               0
# SECURITY_REMEDIATION_EFFORT                      0
# SECURITY_RATING                                  0
# database                                         0
# ANALYSIS_KEY                                 77669
# DIRECTORIES                                  77687
# creationCommitHash                          132159
# TAGS_x                                      132159
# CREATION_ANALYSIS_KEY                       131562
# TAGS_y                                      131562
# dtype: int64

# %% [markdown]
# Is there overlap of tags for the same analysis?

# %%
# No.
dfm_i[dfm_i['TAGS_x'].notnull() & dfm_i['TAGS_y'].notnull()]
# Out:
# Empty DataFrame
# Columns: [COMMIT_HASH, PROJECT_ID, SQ_ANALYSIS_DATE, CLASSES, FILES, FUNCTIONS, COMMENT_LINES, COMMENT_LINES_DENSITY, COMPLEXITY, FILE_COMPLEXITY, CLASS_COMPLEXITY, FUNCTION_COMPLEXITY, FUNCTION_COMPLEXITY_DISTRIBUTION, FILE_COMPLEXITY_DISTRIBUTION, DUPLICATED_LINES, DUPLICATED_BLOCKS, DUPLICATED_FILES, DUPLICATED_LINES_DENSITY, VIOLATIONS, BLOCKER_VIOLATIONS, CRITICAL_VIOLATIONS, INFO_VIOLATIONS, CONFIRMED_ISSUES, LAST_COMMIT_DATE, CODE_SMELLS, BUGS, EFFORT_TO_REACH_MAINTAINABILITY_RATING_A, COGNITIVE_COMPLEXITY, LINES, NCLOC, NCLOC_LANGUAGE_DISTRIBUTION, LINES_TO_COVER, MAJOR_VIOLATIONS, MINOR_VIOLATIONS, OPEN_ISSUES, SQALE_RATING, MISSING_PACKAGE_INFO, PACKAGE, STATEMENTS, UNCOVERED_LINES, SQALE_INDEX, DEVELOPMENT_COST, SQALE_DEBT_RATIO, ALERT_STATUS, QUALITY_GATE_DETAILS, QUALITY_PROFILES, NEW_SQALE_DEBT_RATIO, VULNERABILITIES, RELIABILITY_REMEDIATION_EFFORT, RELIABILITY_RATING, SECURITY_REMEDIATION_EFFORT, SECURITY_RATING, database, ANALYSIS_KEY, DIRECTORIES, creationCommitHash, TAGS_x, CREATION_ANALYSIS_KEY, TAGS_y]
# Index: []
#
# [0 rows x 59 columns]

# %% [markdown]
# ## Bringing together the tags
# By joining the dataframe containing SonarQube measures with the two different tag dataframes (one for each version), there now are two different TAGS columns which need to be filled into one to extract unique analysis for which there are new code smells.

# %%
# since TAGS_x has more values, set TAGS = TAGS_x
dfm_i['TAGS'] = dfm_i['TAGS_x']

# for the missing values of TAGS, set TAGS_y if there is a value
dfm_i['TAGS'] = dfm_i['TAGS'].fillna(dfm_i['TAGS_y'])

# %%
pd.set_option('display.max_rows', None)
missing_values = dfm_i.isnull().sum()
print("Missing Values per Column:")
print(missing_values)
pd.reset_option('display.max_rows')
# Out:
# Missing Values per Column:
# COMMIT_HASH                                  63079
# PROJECT_ID                                       0
# SQ_ANALYSIS_DATE                                 0
# CLASSES                                         20
# FILES                                           18
# FUNCTIONS                                       20
# COMMENT_LINES                                   18
# COMMENT_LINES_DENSITY                           18
# COMPLEXITY                                      20
# FILE_COMPLEXITY                                 20
# CLASS_COMPLEXITY                                20
# FUNCTION_COMPLEXITY                             20
# FUNCTION_COMPLEXITY_DISTRIBUTION              9875
# FILE_COMPLEXITY_DISTRIBUTION                    20
# DUPLICATED_LINES                                 0
# DUPLICATED_BLOCKS                                0
# DUPLICATED_FILES                                 0
# DUPLICATED_LINES_DENSITY                        18
# VIOLATIONS                                       0
# BLOCKER_VIOLATIONS                               0
# CRITICAL_VIOLATIONS                              0
# INFO_VIOLATIONS                                  0
# CONFIRMED_ISSUES                                 0
# LAST_COMMIT_DATE                                53
# CODE_SMELLS                                      0
# BUGS                                             0
# EFFORT_TO_REACH_MAINTAINABILITY_RATING_A         0
# COGNITIVE_COMPLEXITY                            20
# LINES                                           18
# NCLOC                                           18
# NCLOC_LANGUAGE_DISTRIBUTION                     18
# LINES_TO_COVER                                  26
# MAJOR_VIOLATIONS                                 0
# MINOR_VIOLATIONS                                 0
# OPEN_ISSUES                                      0
# SQALE_RATING                                     0
# MISSING_PACKAGE_INFO                             0
# PACKAGE                                          0
# STATEMENTS                                      20
# UNCOVERED_LINES                                 26
# SQALE_INDEX                                      0
# DEVELOPMENT_COST                                 0
# SQALE_DEBT_RATIO                                 0
# ALERT_STATUS                                     0
# QUALITY_GATE_DETAILS                             0
# QUALITY_PROFILES                                18
# NEW_SQALE_DEBT_RATIO                            10
# VULNERABILITIES                                  0
# RELIABILITY_REMEDIATION_EFFORT                   0
# RELIABILITY_RATING                               0
# SECURITY_REMEDIATION_EFFORT                      0
# SECURITY_RATING                                  0
# database                                         0
# ANALYSIS_KEY                                 77669
# DIRECTORIES                                  77687
# creationCommitHash                          132159
# TAGS_x                                      132159
# CREATION_ANALYSIS_KEY                       131562
# TAGS_y                                      131562
# TAGS                                        122973
# dtype: int64

# %% [markdown]
# ## Select variables for model and drop duplicated rows
# Similarly as for the prediction for the amount of code smells, the same variables are selected except for code smells and keeping the identifier columns to remove duplicates and analysis dates.

# %%
variable_list = [
    'PROJECT_ID',
    'SQ_ANALYSIS_DATE',
    'COMMIT_HASH',
    'ANALYSIS_KEY',
    'CLASSES',
    'FILES',
    'LINES',
    'NCLOC',
    'PACKAGE',
    'STATEMENTS',
    'FUNCTIONS',
    'COMMENT_LINES',
    'COMPLEXITY',
    'CLASS_COMPLEXITY',
    'FUNCTION_COMPLEXITY',
    'COGNITIVE_COMPLEXITY',
    'LINES_TO_COVER',
    'UNCOVERED_LINES',
    'DUPLICATED_LINES',
    'DUPLICATED_BLOCKS',
    'DUPLICATED_FILES',
    'COMMENT_LINES_DENSITY',
    'DUPLICATED_LINES_DENSITY',
    'TAGS'
]

dfm_i = dfm_i[variable_list]
dfm_i
# Out:
#        PROJECT_ID     SQ_ANALYSIS_DATE  \
# 0        accumulo  2008-07-07 14:52:05
# 1        accumulo  2008-07-07 12:31:47
# 2        accumulo  2008-07-05 18:54:27
# 3        accumulo  2008-07-03 20:21:40
# 4        accumulo  2008-07-02 00:12:36
# ...           ...                  ...
# 140743        vfs  2002-08-20 06:10:50
# 140744        vfs  2002-08-20 02:57:02
# 140745        vfs  2002-07-19 11:54:15
# 140746        vfs  2002-07-18 16:47:24
# 140747        vfs  2002-07-17 10:23:44
#
#                                      COMMIT_HASH          ANALYSIS_KEY  \
# 0       e0880e263e4bf8662ba3848405200473a25dfc9f                   NaN
# 1       e8774c5ec3a35e042f320540b5f7e66ebd2d9e87                   NaN
# 2       2032ebbd0ed90734da39ca238bbd10dee24d0030                   NaN
# 3       de297d4932e08625a5df146f0802041bb5aeb892                   NaN
# 4       34efaae87639a83b60fdb7274de4b45051025a3a                   NaN
# ...                                          ...                   ...
# 140743                                       NaN  AV4Z-nYtG0XxMwG_Vh5b
# 140744                                       NaN  AV4Z-jElG0XxMwG_Vh5F
# 140745                                       NaN  AV4Z-fA0G0XxMwG_Vh47
# 140746                                       NaN  AV4Z-bDZG0XxMwG_Vh4x
# 140747                                       NaN  AV4Z-W8cG0XxMwG_VhzH
#
#         CLASSES   FILES     LINES     NCLOC  PACKAGE  STATEMENTS  ...  \
# 0        2108.0  1103.0  263680.0  203873.0      164    105125.0  ...
# 1        2108.0  1103.0  262753.0  202956.0      164    105125.0  ...
# 2        2108.0  1103.0  262753.0  202956.0      164    105125.0  ...
# 3        2108.0  1103.0  263643.0  203841.0      164    105125.0  ...
# 4        2108.0  1103.0  263639.0  203837.0      164    105125.0  ...
# ...         ...     ...       ...       ...      ...         ...  ...
# 140743     69.0    65.0    8859.0    4814.0       14      1787.0  ...
# 140744     69.0    65.0    8867.0    4835.0       14      1794.0  ...
# 140745     69.0    65.0    8771.0    4761.0       14      1778.0  ...
# 140746     69.0    65.0    8771.0    4761.0       14      1778.0  ...
# 140747     69.0    65.0    8771.0    4761.0       14      1778.0  ...
#
#         FUNCTION_COMPLEXITY  COGNITIVE_COMPLEXITY  LINES_TO_COVER  \
# 0                       2.5               39453.0        121105.0
# 1                       2.5               39453.0        121105.0
# 2                       2.5               39453.0        121105.0
# 3                       2.5               39453.0        121105.0
# 4                       2.5               39453.0        121105.0
# ...                     ...                   ...             ...
# 140743                  1.6                 445.0          2124.0
# 140744                  1.6                 449.0          2131.0
# 140745                  1.6                 442.0          2104.0
# 140746                  1.6                 442.0          2104.0
# 140747                  1.6                 442.0          2104.0
#
#         UNCOVERED_LINES  DUPLICATED_LINES  DUPLICATED_BLOCKS  \
# 0              121105.0             46445               2410
# 1              121105.0             46301               2408
# 2              121105.0             46301               2408
# 3              121105.0             46445               2410
# 4              121105.0             46445               2410
# ...                 ...               ...                ...
# 140743           2124.0                66                  4
# 140744           2131.0                66                  4
# 140745           2104.0                66                  4
# 140746           2104.0                66                  4
# 140747           2104.0                66                  4
#
#         DUPLICATED_FILES  COMMENT_LINES_DENSITY  DUPLICATED_LINES_DENSITY  \
# 0                    207                    6.2                      17.6
# 1                    205                    6.2                      17.6
# 2                    205                    6.2                      17.6
# 3                    207                    6.2                      17.6
# 4                    207                    6.2                      17.6
# ...                  ...                    ...                       ...
# 140743                 1                   24.2                       0.7
# 140744                 1                   24.1                       0.7
# 140745                 1                   24.1                       0.8
# 140746                 1                   24.1                       0.8
# 140747                 1                   24.1                       0.8
#
#                                                      TAGS
# 0       cwe, bad-practice, unused, cert, suspicious, j...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 140743                   suspicious, error-handling, cert
# 140744                   suspicious, error-handling, cert
# 140745                                                NaN
# 140746                                                NaN
# 140747      antipattern, clumsy, code-smell, bad-practice
#
# [140748 rows x 24 columns]

# %%
dfm_i = dfm_i.drop_duplicates()

# drop identifier columnms
dfm_i = dfm_i.drop(columns = ['COMMIT_HASH', 'ANALYSIS_KEY'])              
dfm_i
# Out:
#        PROJECT_ID     SQ_ANALYSIS_DATE  CLASSES   FILES     LINES     NCLOC  \
# 0        accumulo  2008-07-07 14:52:05   2108.0  1103.0  263680.0  203873.0
# 1        accumulo  2008-07-07 12:31:47   2108.0  1103.0  262753.0  202956.0
# 2        accumulo  2008-07-05 18:54:27   2108.0  1103.0  262753.0  202956.0
# 3        accumulo  2008-07-03 20:21:40   2108.0  1103.0  263643.0  203841.0
# 4        accumulo  2008-07-02 00:12:36   2108.0  1103.0  263639.0  203837.0
# ...           ...                  ...      ...     ...       ...       ...
# 140743        vfs  2002-08-20 06:10:50     69.0    65.0    8859.0    4814.0
# 140744        vfs  2002-08-20 02:57:02     69.0    65.0    8867.0    4835.0
# 140745        vfs  2002-07-19 11:54:15     69.0    65.0    8771.0    4761.0
# 140746        vfs  2002-07-18 16:47:24     69.0    65.0    8771.0    4761.0
# 140747        vfs  2002-07-17 10:23:44     69.0    65.0    8771.0    4761.0
#
#         PACKAGE  STATEMENTS  FUNCTIONS  COMMENT_LINES  ...  \
# 0           164    105125.0    17295.0        13509.0  ...
# 1           164    105125.0    17295.0        13507.0  ...
# 2           164    105125.0    17295.0        13507.0  ...
# 3           164    105125.0    17295.0        13507.0  ...
# 4           164    105125.0    17295.0        13507.0  ...
# ...         ...         ...        ...            ...  ...
# 140743       14      1787.0      425.0         1536.0  ...
# 140744       14      1794.0      422.0         1533.0  ...
# 140745       14      1778.0      421.0         1513.0  ...
# 140746       14      1778.0      421.0         1513.0  ...
# 140747       14      1778.0      421.0         1513.0  ...
#
#         FUNCTION_COMPLEXITY  COGNITIVE_COMPLEXITY  LINES_TO_COVER  \
# 0                       2.5               39453.0        121105.0
# 1                       2.5               39453.0        121105.0
# 2                       2.5               39453.0        121105.0
# 3                       2.5               39453.0        121105.0
# 4                       2.5               39453.0        121105.0
# ...                     ...                   ...             ...
# 140743                  1.6                 445.0          2124.0
# 140744                  1.6                 449.0          2131.0
# 140745                  1.6                 442.0          2104.0
# 140746                  1.6                 442.0          2104.0
# 140747                  1.6                 442.0          2104.0
#
#         UNCOVERED_LINES  DUPLICATED_LINES  DUPLICATED_BLOCKS  \
# 0              121105.0             46445               2410
# 1              121105.0             46301               2408
# 2              121105.0             46301               2408
# 3              121105.0             46445               2410
# 4              121105.0             46445               2410
# ...                 ...               ...                ...
# 140743           2124.0                66                  4
# 140744           2131.0                66                  4
# 140745           2104.0                66                  4
# 140746           2104.0                66                  4
# 140747           2104.0                66                  4
#
#         DUPLICATED_FILES  COMMENT_LINES_DENSITY  DUPLICATED_LINES_DENSITY  \
# 0                    207                    6.2                      17.6
# 1                    205                    6.2                      17.6
# 2                    205                    6.2                      17.6
# 3                    207                    6.2                      17.6
# 4                    207                    6.2                      17.6
# ...                  ...                    ...                       ...
# 140743                 1                   24.2                       0.7
# 140744                 1                   24.1                       0.7
# 140745                 1                   24.1                       0.8
# 140746                 1                   24.1                       0.8
# 140747                 1                   24.1                       0.8
#
#                                                      TAGS
# 0       cwe, bad-practice, unused, cert, suspicious, j...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 140743                   suspicious, error-handling, cert
# 140744                   suspicious, error-handling, cert
# 140745                                                NaN
# 140746                                                NaN
# 140747      antipattern, clumsy, code-smell, bad-practice
#
# [140748 rows x 22 columns]

# %% [markdown]
# ## Select only rows for which tags are filled

# %%
dfm_i = dfm_i[dfm_i['TAGS'].notnull()]
dfm_i
# Out:
#        PROJECT_ID     SQ_ANALYSIS_DATE  CLASSES   FILES     LINES     NCLOC  \
# 0        accumulo  2008-07-07 14:52:05   2108.0  1103.0  263680.0  203873.0
# 7        accumulo  2008-07-01 18:16:28   2108.0  1103.0  263702.0  203883.0
# 21       accumulo  2008-06-12 17:11:34   2108.0  1131.0  278798.0  214326.0
# 23       accumulo  2008-06-10 12:05:27   2107.0  1130.0  278644.0  214193.0
# 25       accumulo  2008-06-10 11:35:56   2107.0  1130.0  278644.0  214194.0
# ...           ...                  ...      ...     ...       ...       ...
# 140737        vfs  2002-08-21 01:40:45     73.0    69.0    9169.0    5005.0
# 140738        vfs  2002-08-21 01:39:47     72.0    68.0    9043.0    4915.0
# 140743        vfs  2002-08-20 06:10:50     69.0    65.0    8859.0    4814.0
# 140744        vfs  2002-08-20 02:57:02     69.0    65.0    8867.0    4835.0
# 140747        vfs  2002-07-17 10:23:44     69.0    65.0    8771.0    4761.0
#
#         PACKAGE  STATEMENTS  FUNCTIONS  COMMENT_LINES  ...  \
# 0           164    105125.0    17295.0        13509.0  ...
# 7           164    105150.0    17299.0        13509.0  ...
# 21          164    111432.0    18092.0        15204.0  ...
# 23          164    111350.0    18090.0        15204.0  ...
# 25          164    111349.0    18091.0        15204.0  ...
# ...         ...         ...        ...            ...  ...
# 140737       16      1837.0      440.0         1563.0  ...
# 140738       15      1803.0      436.0         1553.0  ...
# 140743       14      1787.0      425.0         1536.0  ...
# 140744       14      1794.0      422.0         1533.0  ...
# 140747       14      1778.0      421.0         1513.0  ...
#
#         FUNCTION_COMPLEXITY  COGNITIVE_COMPLEXITY  LINES_TO_COVER  \
# 0                       2.5               39453.0        121105.0
# 7                       2.5               39454.0        121139.0
# 21                      2.6               39465.0        127191.0
# 23                      2.6               39428.0        127106.0
# 25                      2.6               39428.0        127107.0
# ...                     ...                   ...             ...
# 140737                  1.6                 457.0          2185.0
# 140738                  1.6                 446.0          2146.0
# 140743                  1.6                 445.0          2124.0
# 140744                  1.6                 449.0          2131.0
# 140747                  1.6                 442.0          2104.0
#
#         UNCOVERED_LINES  DUPLICATED_LINES  DUPLICATED_BLOCKS  \
# 0              121105.0             46445               2410
# 7              121139.0             46445               2410
# 21             127191.0             46581               2416
# 23             127106.0             46581               2416
# 25             127107.0             46581               2416
# ...                 ...               ...                ...
# 140737           2185.0                66                  4
# 140738           2146.0                66                  4
# 140743           2124.0                66                  4
# 140744           2131.0                66                  4
# 140747           2104.0                66                  4
#
#         DUPLICATED_FILES  COMMENT_LINES_DENSITY  DUPLICATED_LINES_DENSITY  \
# 0                    207                    6.2                      17.6
# 7                    207                    6.2                      17.6
# 21                   210                    6.6                      16.7
# 23                   210                    6.6                      16.7
# 25                   210                    6.6                      16.7
# ...                  ...                    ...                       ...
# 140737                 1                   23.8                       0.7
# 140738                 1                   24.0                       0.7
# 140743                 1                   24.2                       0.7
# 140744                 1                   24.1                       0.7
# 140747                 1                   24.1                       0.8
#
#                                                      TAGS
# 0       cwe, bad-practice, unused, cert, suspicious, j...
# 7                               error-handling, cwe, cert
# 21                                                 design
# 23                                             convention
# 25                                             convention
# ...                                                   ...
# 140737  error-handling, cwe, code-smell, cert, antipat...
# 140738                                                cwe
# 140743                   suspicious, error-handling, cert
# 140744                   suspicious, error-handling, cert
# 140747      antipattern, clumsy, code-smell, bad-practice
#
# [17775 rows x 22 columns]

# %%
len(dfm_i['PROJECT_ID'].unique())
# Out:
# 38

# %% [markdown]
# Only for 38 / 39 projects there are tags.

# %% [markdown]
# ## Cleaning up tags
# Through analysis it has been shown that the distribution of tags is very unsimilar and some tags describe multiple issues instead of one specifically. To ensure the label is consistent, tags that barely appear should be removed and tags that describe multiple issues should be removed.

# %%
all_categories = []

for category_string in dfm_i['TAGS']:
    # handle missing values
    if pd.isna(category_string):
        continue
    # split the string by comma into a list and add to all_categories
    individual_tags = [tag.strip() for tag in category_string.split(',')]
    all_categories.extend(individual_tags)

# count categories in all_categories
category_counts = Counter(all_categories)
category_counts
# Out:
# Counter({'cert': 8207,
#          'error-handling': 6544,
#          'convention': 6099,
#          'cwe': 5172,
#          'suspicious': 4767,
#          'design': 4757,
#          'pitfall': 4455,
#          'brain-overload': 4329,
#          'unused': 3787,
#          'misra': 3411,
#          'bad-practice': 3181,
#          'code-smell': 2869,
#          'antipattern': 2869,
#          'clumsy': 2815,
#          'redundant': 1235,
#          'performance': 1098,
#          'style': 616,
#          'obsolete': 608,
#          'confusing': 523,
#          'java8': 460,
#          'psr2': 219,
#          'lock-in': 75,
#          '': 62,
#          'html5': 52,
#          'serialization': 47,
#          'unpredictable': 44,
#          'multi-threading': 41,
#          'browser-compatibility': 39,
#          'format': 32,
#          'sql': 6,
#          'cross-browser': 1,
#          'user-experience': 1})

# %% [markdown]
# Tags that are built-in are used ([Built-In Rule Tags SonarQube](https://docs.sonarsource.com/sonarqube-server/latest/user-guide/rules/built-in-rule-tags/)). <br>
# Of these tags, some describe a bigger set of issues. These are getting excluded as the focus lies on specifying concrete issues. The tags present here are the following: 'cert', 'cwe', 'misra', 'psr2' and 'code-smell'. <br>
# There are rules that aren't properly explained by SonarQube but are to be taken by word ([Rule Tags Issue in SonarQube Forum](https://community.sonarsource.com/t/sonarqube-rule-tags/1251)). These are used if they are understandable enough. <br>
# Style for example encases multiple rules that are very close to convention at times or fraudulent ([Style Tag Issue in SonarQube Forum](https://community.sonarsource.com/t/style-tag-applied-inconsistently/37939)).<br>
# Tags which occur less than a 100 times are considered the tail of the distribution and removed. <br>
# After this selection, the remaining tags are: 'error-handling', 'convention', 'suspicious', 'pitfall', 'brain-overload', 'unused', 'bad-practice', 'clumsy', 'antipattern', 'redundant', 'performance', 'obsolete' and 'confusing'.

# %%
valid_tags = {'error-handling','convention','suspicious','pitfall','design','brain-overload','unused','bad-practice','clumsy',
         'antipattern','redundant','performance','obsolete','confusing'}

# transform tags for analysis to lists
dfm_i.loc[:, 'TAGS'] = dfm_i['TAGS'].str.split(',')

# filter tags present in analysis based on validity
dfm_i.loc[:, 'TAGS'] = dfm_i['TAGS'].apply(
    lambda tags: [tag.strip() for tag in tags if tag.strip() in valid_tags]
)

dfm_i
# Out:
#        PROJECT_ID     SQ_ANALYSIS_DATE  CLASSES   FILES     LINES     NCLOC  \
# 0        accumulo  2008-07-07 14:52:05   2108.0  1103.0  263680.0  203873.0
# 7        accumulo  2008-07-01 18:16:28   2108.0  1103.0  263702.0  203883.0
# 21       accumulo  2008-06-12 17:11:34   2108.0  1131.0  278798.0  214326.0
# 23       accumulo  2008-06-10 12:05:27   2107.0  1130.0  278644.0  214193.0
# 25       accumulo  2008-06-10 11:35:56   2107.0  1130.0  278644.0  214194.0
# ...           ...                  ...      ...     ...       ...       ...
# 140737        vfs  2002-08-21 01:40:45     73.0    69.0    9169.0    5005.0
# 140738        vfs  2002-08-21 01:39:47     72.0    68.0    9043.0    4915.0
# 140743        vfs  2002-08-20 06:10:50     69.0    65.0    8859.0    4814.0
# 140744        vfs  2002-08-20 02:57:02     69.0    65.0    8867.0    4835.0
# 140747        vfs  2002-07-17 10:23:44     69.0    65.0    8771.0    4761.0
#
#         PACKAGE  STATEMENTS  FUNCTIONS  COMMENT_LINES  ...  \
# 0           164    105125.0    17295.0        13509.0  ...
# 7           164    105150.0    17299.0        13509.0  ...
# 21          164    111432.0    18092.0        15204.0  ...
# 23          164    111350.0    18090.0        15204.0  ...
# 25          164    111349.0    18091.0        15204.0  ...
# ...         ...         ...        ...            ...  ...
# 140737       16      1837.0      440.0         1563.0  ...
# 140738       15      1803.0      436.0         1553.0  ...
# 140743       14      1787.0      425.0         1536.0  ...
# 140744       14      1794.0      422.0         1533.0  ...
# 140747       14      1778.0      421.0         1513.0  ...
#
#         FUNCTION_COMPLEXITY  COGNITIVE_COMPLEXITY  LINES_TO_COVER  \
# 0                       2.5               39453.0        121105.0
# 7                       2.5               39454.0        121139.0
# 21                      2.6               39465.0        127191.0
# 23                      2.6               39428.0        127106.0
# 25                      2.6               39428.0        127107.0
# ...                     ...                   ...             ...
# 140737                  1.6                 457.0          2185.0
# 140738                  1.6                 446.0          2146.0
# 140743                  1.6                 445.0          2124.0
# 140744                  1.6                 449.0          2131.0
# 140747                  1.6                 442.0          2104.0
#
#         UNCOVERED_LINES  DUPLICATED_LINES  DUPLICATED_BLOCKS  \
# 0              121105.0             46445               2410
# 7              121139.0             46445               2410
# 21             127191.0             46581               2416
# 23             127106.0             46581               2416
# 25             127107.0             46581               2416
# ...                 ...               ...                ...
# 140737           2185.0                66                  4
# 140738           2146.0                66                  4
# 140743           2124.0                66                  4
# 140744           2131.0                66                  4
# 140747           2104.0                66                  4
#
#         DUPLICATED_FILES  COMMENT_LINES_DENSITY  DUPLICATED_LINES_DENSITY  \
# 0                    207                    6.2                      17.6
# 7                    207                    6.2                      17.6
# 21                   210                    6.6                      16.7
# 23                   210                    6.6                      16.7
# 25                   210                    6.6                      16.7
# ...                  ...                    ...                       ...
# 140737                 1                   23.8                       0.7
# 140738                 1                   24.0                       0.7
# 140743                 1                   24.2                       0.7
# 140744                 1                   24.1                       0.7
# 140747                 1                   24.1                       0.8
#
#                                                      TAGS
# 0       [bad-practice, unused, suspicious, confusing, ...
# 7                                        [error-handling]
# 21                                               [design]
# 23                                           [convention]
# 25                                           [convention]
# ...                                                   ...
# 140737                      [error-handling, antipattern]
# 140738                                                 []
# 140743                       [suspicious, error-handling]
# 140744                       [suspicious, error-handling]
# 140747                [antipattern, clumsy, bad-practice]
#
# [17775 rows x 22 columns]

# %%
# filter rows for which TAGS is empty ([])
dfm_i[~dfm_i['TAGS'].apply(bool)]
# Out:
#        PROJECT_ID     SQ_ANALYSIS_DATE  CLASSES   FILES     LINES     NCLOC  \
# 71       accumulo  2008-05-13 22:21:22   2111.0  1135.0  288668.0  209335.0
# 1556     accumulo  2012-01-19 12:18:19   4114.0  1284.0  409278.0  303506.0
# 1570     accumulo  2012-01-17 22:35:08   4114.0  1284.0  409289.0  303517.0
# 1999     accumulo  2011-10-11 15:00:15   4147.0  1296.0  415080.0  308336.0
# 2368     accumulo  2011-09-03 21:22:56   4274.0  1365.0  429606.0  319073.0
# ...           ...                  ...      ...     ...       ...       ...
# 140648        vfs  2002-11-23 00:11:53    124.0   111.0   19568.0    7811.0
# 140661        vfs  2002-11-17 03:39:21    119.0   106.0   18862.0    7614.0
# 140669        vfs  2002-11-01 03:24:03    115.0   102.0   18156.0    7336.0
# 140716        vfs  2002-10-21 02:52:41     91.0    84.0   11148.0    6189.0
# 140738        vfs  2002-08-21 01:39:47     72.0    68.0    9043.0    4915.0
#
#         PACKAGE  STATEMENTS  FUNCTIONS  COMMENT_LINES  ...  \
# 71          164    111635.0    18132.0        15332.0  ...
# 1556        176    156785.0    27822.0        21390.0  ...
# 1570        176    156794.0    27822.0        21390.0  ...
# 1999        177    159637.0    28122.0        21630.0  ...
# 2368        186    165099.0    28915.0        22393.0  ...
# ...         ...         ...        ...            ...  ...
# 140648       21      2607.0      746.0         2342.0  ...
# 140661       21      2602.0      725.0         2246.0  ...
# 140669       21      2524.0      692.0         2176.0  ...
# 140716       19      2176.0      560.0         1824.0  ...
# 140738       15      1803.0      436.0         1553.0  ...
#
#         FUNCTION_COMPLEXITY  COGNITIVE_COMPLEXITY  LINES_TO_COVER  \
# 71                      2.5               39513.0        124308.0
# 1556                    2.5               54500.0        179581.0
# 1570                    2.5               54506.0        179590.0
# 1999                    2.5               55519.0        182844.0
# 2368                    2.5               57452.0        189042.0
# ...                     ...                   ...             ...
# 140648                  1.6                 716.0          3198.0
# 140661                  1.6                 707.0          3178.0
# 140669                  1.6                 684.0          3078.0
# 140716                  1.7                 602.0          2617.0
# 140738                  1.6                 446.0          2146.0
#
#         UNCOVERED_LINES  DUPLICATED_LINES  DUPLICATED_BLOCKS  \
# 71             124308.0             46443               2422
# 1556           179581.0             73618               3255
# 1570           179590.0             73618               3255
# 1999           182844.0             76159               3227
# 2368           189042.0             78851               3335
# ...                 ...               ...                ...
# 140648           3198.0               122                  6
# 140661           3178.0               122                  6
# 140669           3078.0               122                  6
# 140716           2617.0               150                  6
# 140738           2146.0                66                  4
#
#         DUPLICATED_FILES  COMMENT_LINES_DENSITY  DUPLICATED_LINES_DENSITY  \
# 71                   209                    6.8                      16.1
# 1556                 226                    6.6                      18.0
# 1570                 226                    6.6                      18.0
# 1999                 228                    6.6                      18.3
# 2368                 241                    6.6                      18.4
# ...                  ...                    ...                       ...
# 140648                 3                   23.1                       0.6
# 140661                 3                   22.8                       0.6
# 140669                 3                   22.9                       0.7
# 140716                 3                   22.8                       1.3
# 140738                 1                   24.0                       0.7
#
#         TAGS
# 71        []
# 1556      []
# 1570      []
# 1999      []
# 2368      []
# ...      ...
# 140648    []
# 140661    []
# 140669    []
# 140716    []
# 140738    []
#
# [596 rows x 22 columns]

# %%
# filter rows for which TAGS is filled
dfm_i = dfm_i[dfm_i['TAGS'].apply(bool)]

# %%
len(dfm_i['PROJECT_ID'].unique())
# Out:
# 38

# %% [markdown]
# Only 38 / 39 projects have analysis that belong to the subset of valid tags.

# %%
# transform tags back to strings
dfm_i.loc[:, 'TAGS'] = dfm_i['TAGS'].apply(lambda x: ', '.join(x))

# %%
dfm_i.to_csv(os.path.join(data_dir, 'measures+tags.csv'), index = False)
