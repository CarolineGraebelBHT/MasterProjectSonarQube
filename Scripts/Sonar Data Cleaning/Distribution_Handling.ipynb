# %% [markdown]
# # Understanding how to use the SonarQube distribution software metrics

# %%
import pandas as pd
import os

# %%
# data import
current_dir = os.getcwd()

# construct path to the project data folder
data_dir = os.path.join(current_dir, '..', '..', 'Data', 'Sonar_Measures')

# load SonarQube measure data of version 1 and 2, cleaned
df = pd.read_csv(os.path.join(data_dir, 'sonar_measures_v1_v2_no_statics.csv'), low_memory=False)

df
# Out:
#        PROJECT_ID     SQ_ANALYSIS_DATE  CLASSES   FILES  FUNCTIONS  \
# 0        accumulo  2008-07-07 14:52:05   2108.0  1103.0    17295.0
# 1        accumulo  2008-07-07 12:31:47   2108.0  1103.0    17295.0
# 2        accumulo  2008-07-05 18:54:27   2108.0  1103.0    17295.0
# 3        accumulo  2008-07-03 20:21:40   2108.0  1103.0    17295.0
# 4        accumulo  2008-07-02 00:12:36   2108.0  1103.0    17295.0
# ...           ...                  ...      ...     ...        ...
# 140743        vfs  2002-08-20 06:10:50     69.0    65.0      425.0
# 140744        vfs  2002-08-20 02:57:02     69.0    65.0      422.0
# 140745        vfs  2002-07-19 11:54:15     69.0    65.0      421.0
# 140746        vfs  2002-07-18 16:47:24     69.0    65.0      421.0
# 140747        vfs  2002-07-17 10:23:44     69.0    65.0      421.0
#
#         COMMENT_LINES  COMMENT_LINES_DENSITY  COMPLEXITY  FILE_COMPLEXITY  \
# 0             13509.0                    6.2     43137.0             40.6
# 1             13507.0                    6.2     43137.0             40.6
# 2             13507.0                    6.2     43137.0             40.6
# 3             13507.0                    6.2     43137.0             40.6
# 4             13507.0                    6.2     43137.0             40.6
# ...               ...                    ...         ...              ...
# 140743         1536.0                   24.2       690.0             10.6
# 140744         1533.0                   24.1       693.0             10.7
# 140745         1513.0                   24.1       687.0             10.6
# 140746         1513.0                   24.1       687.0             10.6
# 140747         1513.0                   24.1       687.0             10.6
#
#         CLASS_COMPLEXITY  ...  \
# 0                   20.4  ...
# 1                   20.4  ...
# 2                   20.4  ...
# 3                   20.4  ...
# 4                   20.4  ...
# ...                  ...  ...
# 140743              10.0  ...
# 140744              10.0  ...
# 140745              10.0  ...
# 140746              10.0  ...
# 140747              10.0  ...
#
#                                      QUALITY_GATE_DETAILS  \
# 0       {"level":"ERROR","conditions":[{"metric":"bloc...
# 1       {"level":"ERROR","conditions":[{"metric":"bloc...
# 2       {"level":"ERROR","conditions":[{"metric":"bloc...
# 3       {"level":"ERROR","conditions":[{"metric":"bloc...
# 4       {"level":"ERROR","conditions":[{"metric":"bloc...
# ...                                                   ...
# 140743  {"level":"ERROR";"conditions":[{"metric":"bloc...
# 140744  {"level":"ERROR";"conditions":[{"metric":"bloc...
# 140745  {"level":"ERROR";"conditions":[{"metric":"bloc...
# 140746  {"level":"ERROR";"conditions":[{"metric":"bloc...
# 140747  {"level":"ERROR";"conditions":[{"metric":"bloc...
#
#                                          QUALITY_PROFILES  \
# 0       [{"key":"css-sonar-way-41536","language":"css"...
# 1       [{"key":"css-sonar-way-41536","language":"css"...
# 2       [{"key":"css-sonar-way-41536","language":"css"...
# 3       [{"key":"css-sonar-way-41536","language":"css"...
# 4       [{"key":"css-sonar-way-41536","language":"css"...
# ...                                                   ...
# 140743  [{"key":"java-sonar-way-04122";"language":"jav...
# 140744  [{"key":"java-sonar-way-04122";"language":"jav...
# 140745  [{"key":"java-sonar-way-04122";"language":"jav...
# 140746  [{"key":"java-sonar-way-04122";"language":"jav...
# 140747  [{"key":"java-sonar-way-04122";"language":"jav...
#
#        NEW_SQALE_DEBT_RATIO  VULNERABILITIES  RELIABILITY_REMEDIATION_EFFORT  \
# 0                  0.000000              838                            7322
# 1                  0.222222              838                            7081
# 2                  0.222222              838                            7081
# 3                  0.674560              838                            7322
# 4                  0.671668              838                            7322
# ...                     ...              ...                             ...
# 140743             2.025316                1                               0
# 140744             2.184236                1                               0
# 140745             2.613333                1                               0
# 140746             2.613333                1                               0
# 140747             2.613333                1                               0
#
#         RELIABILITY_RATING  SECURITY_REMEDIATION_EFFORT  SECURITY_RATING  \
# 0                        5                         9505                4
# 1                        5                         9505                4
# 2                        5                         9505                4
# 3                        5                         9505                4
# 4                        5                         9505                4
# ...                    ...                          ...              ...
# 140743                   1                           30                4
# 140744                   1                           30                4
# 140745                   1                           30                4
# 140746                   1                           30                4
# 140747                   1                           30                4
#
#         database  DIRECTORIES
# 0       Version1          NaN
# 1       Version1          NaN
# 2       Version1          NaN
# 3       Version1          NaN
# 4       Version1          NaN
# ...          ...          ...
# 140743  Version2         14.0
# 140744  Version2         14.0
# 140745  Version2         14.0
# 140746  Version2         14.0
# 140747  Version2         14.0
#
# [140748 rows x 53 columns]

# %% [markdown]
# ## Finding out all unique languages occurring in the dataset

# %%
unique_languages = set()

for row in df['NCLOC_LANGUAGE_DISTRIBUTION'].dropna():
    # get list of languages for one row
    pairs = row.split(';')
    for pair in pairs:
        # for valid strings ('css=92') extract language used
        if '=' in pair:
            lang = pair.split('=')[0]
            unique_languages.add(lang)

print(f"Unique languages used in the projects: {unique_languages}")
# Out:
# Unique languages used in the projects: {'css', 'java', 'scss', 'less', 'web', 'js', 'php', 'xml'}

# %% [markdown]
# ## Creating columns that contain the amount of code lines for each language

# %%
all_languages = {'less', 'css', 'scss', 'xml', 'php', 'js', 'web', 'java'}

# function to parse the distribution string into a dictionary
def parse_language_distribution(distribution_string):
    # for missing values return empty dict
    if pd.isna(distribution_string) or distribution_string == '':
        return {}

    # initialise dict
    language_data = {}

    # replace , with ; to catch rows where languages are split by , instead of ;
    distribution_string = distribution_string.replace(',', ';')

    # create list of languages present in a row
    pairs = distribution_string.split(';')

    # extract language and amount of code lines (value) for each item in pairs and add it to the dict
    for pair in pairs:
        if '=' in pair:
            language, value = pair.split('=')
            language_data[language] = int(value)
    return language_data

# apply parsing function to distribution column
df['parsed_languages'] = df['NCLOC_LANGUAGE_DISTRIBUTION'].apply(parse_language_distribution)

# create new columns for each language and fill them with the according values
# set 0 if a language is not present in the distribution
for lang in all_languages:
    df[lang] = df['parsed_languages'].apply(lambda x: x.get(lang, 0))

# drop helper column 'parsed_languages'
df = df.drop(columns=['parsed_languages'])
df
# Out:
#        PROJECT_ID     SQ_ANALYSIS_DATE  CLASSES   FILES  FUNCTIONS  \
# 0        accumulo  2008-07-07 14:52:05   2108.0  1103.0    17295.0
# 1        accumulo  2008-07-07 12:31:47   2108.0  1103.0    17295.0
# 2        accumulo  2008-07-05 18:54:27   2108.0  1103.0    17295.0
# 3        accumulo  2008-07-03 20:21:40   2108.0  1103.0    17295.0
# 4        accumulo  2008-07-02 00:12:36   2108.0  1103.0    17295.0
# ...           ...                  ...      ...     ...        ...
# 140743        vfs  2002-08-20 06:10:50     69.0    65.0      425.0
# 140744        vfs  2002-08-20 02:57:02     69.0    65.0      422.0
# 140745        vfs  2002-07-19 11:54:15     69.0    65.0      421.0
# 140746        vfs  2002-07-18 16:47:24     69.0    65.0      421.0
# 140747        vfs  2002-07-17 10:23:44     69.0    65.0      421.0
#
#         COMMENT_LINES  COMMENT_LINES_DENSITY  COMPLEXITY  FILE_COMPLEXITY  \
# 0             13509.0                    6.2     43137.0             40.6
# 1             13507.0                    6.2     43137.0             40.6
# 2             13507.0                    6.2     43137.0             40.6
# 3             13507.0                    6.2     43137.0             40.6
# 4             13507.0                    6.2     43137.0             40.6
# ...               ...                    ...         ...              ...
# 140743         1536.0                   24.2       690.0             10.6
# 140744         1533.0                   24.1       693.0             10.7
# 140745         1513.0                   24.1       687.0             10.6
# 140746         1513.0                   24.1       687.0             10.6
# 140747         1513.0                   24.1       687.0             10.6
#
#         CLASS_COMPLEXITY  ...  database DIRECTORIES  css  scss    java  less  \
# 0                   20.4  ...  Version1         NaN  311     0  197426     0
# 1                   20.4  ...  Version1         NaN  311     0  197426     0
# 2                   20.4  ...  Version1         NaN  311     0  197426     0
# 3                   20.4  ...  Version1         NaN  311     0  197426     0
# 4                   20.4  ...  Version1         NaN  311     0  197426     0
# ...                  ...  ...       ...         ...  ...   ...     ...   ...
# 140743              10.0  ...  Version2        14.0    0     0    4814     0
# 140744              10.0  ...  Version2        14.0    0     0    4835     0
# 140745              10.0  ...  Version2        14.0    0     0    4761     0
# 140746              10.0  ...  Version2        14.0    0     0    4761     0
# 140747              10.0  ...  Version2        14.0    0     0    4761     0
#
#          web  js  php   xml
# 0       1674   5    0  4457
# 1        789   5    0  4425
# 2        789   5    0  4425
# 3       1674   5    0  4425
# 4       1674   5    0  4421
# ...      ...  ..  ...   ...
# 140743     0   0    0     0
# 140744     0   0    0     0
# 140745     0   0    0     0
# 140746     0   0    0     0
# 140747     0   0    0     0
#
# [140748 rows x 61 columns]

# %% [markdown]
# ## Are the languages filled properly for missing distributions?

# %%
df[df['NCLOC_LANGUAGE_DISTRIBUTION'].isna()][['NCLOC_LANGUAGE_DISTRIBUTION', 'less', 'css', 'scss', 'xml', 'php', 'js', 'web', 'java']]
# Out:
#        NCLOC_LANGUAGE_DISTRIBUTION  less  css  scss  xml  php  js  web  java
# 83596                          NaN     0    0     0    0    0   0    0     0
# 103801                         NaN     0    0     0    0    0   0    0     0
# 104417                         NaN     0    0     0    0    0   0    0     0
# 104418                         NaN     0    0     0    0    0   0    0     0
# 107114                         NaN     0    0     0    0    0   0    0     0
# 107115                         NaN     0    0     0    0    0   0    0     0
# 110583                         NaN     0    0     0    0    0   0    0     0
# 110584                         NaN     0    0     0    0    0   0    0     0
# 118791                         NaN     0    0     0    0    0   0    0     0
# 118792                         NaN     0    0     0    0    0   0    0     0
# 118793                         NaN     0    0     0    0    0   0    0     0
# 130167                         NaN     0    0     0    0    0   0    0     0
# 130168                         NaN     0    0     0    0    0   0    0     0
# 132068                         NaN     0    0     0    0    0   0    0     0
# 132069                         NaN     0    0     0    0    0   0    0     0
# 135362                         NaN     0    0     0    0    0   0    0     0
# 137328                         NaN     0    0     0    0    0   0    0     0
# 138668                         NaN     0    0     0    0    0   0    0     0

# %%
df.to_csv(os.path.join(data_dir, 'sonar_measures_v1_v2_cleaned+ncloc_distr.csv'), index = False)
